# %% [markdown]
# ## Base Model: Neutral

# %%
import pandas as pd
import gurobipy as gb
from gurobipy import *

# Define the probabilities of scenarios
Ps = {
    "current": 0.5,
    "net_zero": 0.5,
}

# Define Sets
S = ["current", "net_zero"]
T = [2025, 2030, 2035]
G = ["wind", "solar", "hydro", "nuclear", "natural_gas", "geothermal", "oil", "coal"]

# Read each sheet into a DataFrame
df_Dst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Electricity Demand')
df_Lgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Output Targets')
df_Ugst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Capacity Targets')
df_Eg = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Factor')
df_Cgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Cost')
df_Bst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Cap')
df_Kst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Capital Expenditure Budget')

df_dev_e = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_E')
df_dev_g = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_G')
df_dev_q = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_Q')
df_dev_c = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_C')

# Convert DataFrames to dictionaries
Dst = df_Dst.set_index(['Scenario', 'Year']).to_dict()['Electricity Demand (GWh)']
Lgst = df_Lgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Output Targets (GWh)']
Ugst = df_Ugst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Capacity Targets (GW)']
Cgst = df_Cgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Cost (Millions$/GW)']
Bst = df_Bst.set_index(['Technology','Scenario', 'Year']).to_dict()['Emissions Cap (MtCO2)']
Eg = df_Eg.set_index(['Technology','Scenario','Year']).to_dict()['Emissions Factor (MtCO2/GWh)']
Kst = {scenario: df_Kst[df_Kst['Scenario'] == scenario].set_index('Year')['Value'].to_dict() for scenario in df_Kst['Scenario'].unique()}

dev_e_plus = df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_g_plus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_q_plus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_c_plus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% UB']

dev_e_minus= df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_g_minus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_q_minus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_c_minus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% LB']

# Create Model
m = Model("CanadaEnergyModel")

# Decision Variables
X = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation_Capacity")
Y = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation")
Z = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Emissions")
C = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cost")
W = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Gen_Emission_Linkage")
V = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cap_Cost_Linkage")

# Deviation Variables
et_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Emissions_Deviation")
et_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Emissions_Deviation")
ct_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Cost_Deviation")
ct_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Cost_Deviation")
gt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Deviation")
gt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Deviation")
qt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Capacity_Deviation")
qt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Capacity_Deviation")
# Set upper bounds for positive deviation variables based on data from Excel
for g in G:
    for s in S:
        for t in T:
            et_plus[g, s, t].ub = dev_e_plus.get((g, s, t), 0)
            ct_plus[g, s, t].ub = dev_c_plus.get((g, s, t), 0)
            gt_plus[g, s, t].ub = dev_g_plus.get((g, s, t), 0)
            qt_plus[g,s,t].ub = dev_q_plus.get((g,s,t), 0)


#Set upper bounds for negative deviation variables based on data from Excel
for g in G:
   for s in S:
        for t in T:
            et_minus[g,s,t].ub = dev_e_minus.get((g,s,t), 0)
            ct_minus[g,s,t].ub = dev_c_minus.get((g,s,t), 0)
            gt_minus[g,s,t].ub = dev_g_minus.get((g,s,t), 0)
            qt_minus[g,s,t].ub = dev_q_minus.get((g,s,t), 0)
            

# Constraints

# Probability sum constraint
probability_sum_constraint = m.addConstr((sum(Ps[s] for s in S) == 1), name="Probability_Sum")

# Electricity demand constraints
demand_constraints = {}
for s in S:
    for t in T:
        demand_constraints[s, t] = m.addConstr(
            sum(Y[g, s, t] for g in G) <= Dst[(s, t)],
            name=f"Demand_{s}_{t}",
        )

# Generation capacity limit constraints
capacity_limit_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_limit_constraints[g, s, t] = m.addConstr(
                Y[g, s, t] <= X[g, s, t] * 8760 * 1,
                name=f"Capacity_Limit_{g}_{s}_{t}",
            )

# Emission constraints
emission_constraints = {}
for s in S:
    for t in T:
        emission_constraints[s, t] = m.addConstr(
            sum(Z[g, s, t] for g in G) <= (Bst[(g,s, t)] + et_plus.sum('*', s, t) - et_minus.sum('*', s, t)),
            name=f"Emission_{g}_{s}_{t}",
        )

# Capital expenditure constraints
for s in S:
    for t in T:
        m.addConstr(
            sum(C[g, s, t] for g in G) <= Kst[s][t] + ct_plus.sum('*', s, t) - ct_minus.sum('*', s, t),
            name=f"CapEx_{s}_{t}",
        )

# Generation target constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] >= Lgst[(g, s, t)] - gt_plus[g, s, t] + gt_minus[g, s, t],
                name=f"Generation_Target_{g}_{s}_{t}",
            )

# Generation capacity target constraints
capacity_target_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_target_constraints[g, s, t] = m.addConstr(
                X[g, s, t] >= Ugst[(g, s, t)] - qt_plus[g, s, t] + qt_minus[g, s, t],
                name=f"Capacity_Target_{g}_{s}_{t}",
            )


# Define the emissions linking constraints dictionary
emissions_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            emissions_linking_constraints[g, s, t] = m.addConstr(
                Z[g, s, t] == Y[g, s, t] * Eg[g, s, t],
                name=f"Emission_Linking_{g}_{s}_{t}",
            )


# Cost linking constraints
cost_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            cost_linking_constraints[g, s, t] = m.addConstr(
                C[g, s, t] == V[g, s, t] * Cgst[(g, s, t)],
                name=f"Cost_Linking_{g}_{s}_{t}",
            )

# Emissions goal achievement constraints
for g in G:
    for s in S:
       for t in T:
            m.addConstr(
                Z[g, s, t] - et_plus[g, s, t] + et_minus[g, s, t]
               == Eg[g, s, t],
               name=f"Emissions_Goal_{g}_{s}_{t}",
            )

# Cost goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                C[g, s, t] - ct_plus[g, s, t] + ct_minus[g, s, t]
                == Bst[g,s, t],
                name=f"Cost_Goal_{g}_{s}_{t}",
            )

# Generation goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] - gt_plus[g, s, t] + gt_minus[g, s, t]
                == Lgst[g, s, t],
                name=f"Generation_Goal_{g}_{s}_{t}",
            )

# Generation capacity goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                X[g, s, t] - qt_plus[g, s, t] + qt_minus[g, s, t]
                == Ugst[g, s, t],
                name=f"Capacity_Goal_{g}_{s}_{t}",
            )

# Define the multiple objectives
objectives = {
    "Emissions_Deviation": {"expr": LinExpr(), "priority": 3},
    "Generation_Deviation": {"expr": LinExpr(), "priority": 2},
    "Capacity_Deviation": {"expr": LinExpr(), "priority": 1},
    "Cost_Deviation": {"expr": LinExpr(), "priority": 0},
}

# Loop through scenarios
for s in S:
  # Loop through time periods
  for t in T:
    # Loop through generation technologies
    for g in G:
      # Objective expressions with g, s, t indexing
      objectives["Emissions_Deviation"]["expr"] += Ps[s] * (et_plus[g,s,t] + et_minus[g,s,t])
      objectives["Generation_Deviation"]["expr"] += Ps[s] * (gt_plus[g,s,t] + gt_minus[g,s,t])
      objectives["Capacity_Deviation"]["expr"] += Ps[s] * (qt_plus[g,s,t] + qt_minus[g,s,t])
      objectives["Cost_Deviation"]["expr"] += Ps[s] * (ct_plus[g,s,t] + ct_minus[g,s,t])

# Set the objectives using setObjectiveN
for i, (obj_name, obj_data) in enumerate(objectives.items()):
  m.setObjectiveN(obj_data["expr"], index=i, priority=obj_data["priority"], name=obj_name)

# Optimize the model
m.optimize()

# Rounding function
def round_to_2(val):
    return round(val, 2)


if m.status == GRB.OPTIMAL:
    print("Optimal Solution Found. Printing Values:")

    for s in S:
        for t in T:
            print(f"\nScenario: {s}, Time Period: {t}")
            for g in G:
                print(f"  Technology: {g}")
                generation = Y[g, s, t].x  # Use actual generation instead of capacity
                cost_per_gw = Cgst[(g, s, t)]
                total_cost = generation * cost_per_gw
                print(f"    Generation: {round_to_2(generation)} GWh")
                print(f"    Generation Capacity: {round_to_2(X[g, s, t].x)} GW")
                print(f"    Emissions: {round_to_2(Z[g, s, t].x)} MtCO2e")
                print(f"    Costs: ${round_to_2(total_cost)}")
                # Adding unrounded positive and negative deviations
                print(f"    Positive Emissions Deviation: {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"    Negative Emissions Deviation: {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")
                print(f"    Positive Cost Deviation: {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")
                print(f"    Negative Cost Deviation: {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Deviation: {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Deviation: {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Capacity Deviation: {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Capacity Deviation: {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

if m.status == GRB.OPTIMAL:
    
    # Retrieve and print the values for each objective
    for i, obj_name in enumerate(objectives.keys()):
        m.setParam(GRB.Param.ObjNumber, i)
        obj_value = m.ObjNVal
        print(f"Objective '{obj_name}' Value: {obj_value}")

    # Print rounded variable values
    print("Variable Values:")
    for s in S:
        for t in T:
            for g in G:

                # Generation capacity
                rounded_X = round_to_2(X[g, s, t].x) if X[g, s, t] is not None else 0
                print(f"{X[g, s, t].varName} = {rounded_X}")

                # Generation
                rounded_Y = round_to_2(Y[g, s, t].x) if Y[g, s, t] is not None else 0
                print(f"{Y[g, s, t].varName} = {rounded_Y}")

                # Emissions
                rounded_Z = round_to_2(Z[g, s, t].x) if Z[g, s, t] is not None else 0
                print(f"{Z[g, s, t].varName} = {rounded_Z}")

                # Costs
                rounded_C = round_to_2(C[g, s, t].x) if C[g, s, t] is not None else 0
                print(f"{C[g, s, t].varName} = {rounded_C}")

                # Emission linkage
                rounded_W = round_to_2(W[g, s, t].x) if W[g, s, t] is not None else 0
                print(f"{W[g, s, t].varName} = {rounded_W}")

                # Cost linkage
                rounded_V = round_to_2(V[g, s, t].x) if V[g, s, t] is not None else 0
                print(f"{V[g, s, t].varName} = {rounded_V}")

                # Emissions deviation
                print(f"{et_plus[g, s, t].varName} = {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"{et_minus[g, s, t].varName} = {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")

                # Cost deviation
                print(f"{ct_plus[g, s, t].varName} = {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")

                print(f"{ct_minus[g, s, t].varName} = {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")

                # Generation deviation
                print(f"{gt_plus[g, s, t].varName} = {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")

                print(f"{gt_minus[g, s, t].varName} = {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")

                # Capacity deviation
                print(f"{qt_plus[g, s, t].varName} = {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")

                print(f"{qt_minus[g, s, t].varName} = {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

        # Print totals for each decision variable in each scenario and time period
        for s in S:
            for t in T:
                total_gen_st = sum(Y[g, s, t].x for g in G)
                total_cap_st = sum(X[g, s, t].x for g in G)
                total_emission_st = sum(Z[g, s, t].x for g in G)
                total_cost_st = sum(C[g, s, t].x for g in G)

                print("--------------------------------------------------")
                print(f"Scenario: {s}, Time Period: {t}")
                print(f"Total Generation (GWh): {round_to_2(total_gen_st)}")
                print(f"Total Capacity (GW): {round_to_2(total_cap_st)}")
                print(f"Total Emissions (MtCO2e): {round_to_2(total_emission_st)}")
                print(f"Total Cost (Million CAD): ${round_to_2(total_cost_st)}")
                print("--------------------------------------------------\n")

        # Sum decision variables over G, S, and T dimensions for overall total
        total_gen = sum(Y[g, s, t].x for g in G for s in S for t in T)
        total_cap = sum(X[g, s, t].x for g in G for s in S for t in T)
        total_emission = sum(Z[g, s, t].x for g in G for s in S for t in T)
        total_cost = sum(C[g, s, t].x for g in G for s in S for t in T)

        print("\nOverall Total Across All Scenarios and Time Periods:")
        print(f"Total Generation (GWh): {round_to_2(total_gen)}")
        print(f"Total Capacity (GW): {round_to_2(total_cap)}")
        print(f"Total Emissions (MtCO2e): {round_to_2(total_emission)}")
        print(f"Total Cost (Million CAD): ${round_to_2(total_cost)}")

else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 451 rows, 672 columns and 1458 nonzeros
# Model fingerprint: 0x3b7445fd
# Variable types: 672 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 9e+03]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [2e+00, 5e+05]
#   RHS range        [4e-04, 9e+05]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 4 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 245 rows and 254 columns
# Presolved: 206 rows and 418 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (Emissions_Deviatio) ...
# ---------------------------------------------------------------------------
#
# Presolve removed 206 rows and 418 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2348036e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.234803602e+02
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Generation_Deviati) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1064838e+05   0.000000e+00   5.000000e+01      0s
#       22    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 (Capacity_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2438145e+02   0.000000e+00   2.437000e+03      0s
#       46    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 46 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 (Cost_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4785939e+02   0.000000e+00   4.200000e+01      0s
#       24    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.08 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 4
#
# Optimal Solution Found. Printing Values:
#
# Scenario: current, Time Period: 2025
#   Technology: wind
#     Generation: 57101.82 GWh
#     Generation Capacity: 17.3 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $177035.43
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 12140.31 GWh
#     Generation Capacity: 7.52 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28592.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 403350.8 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4547860.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78631.37 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1466147.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 106529.07 GWh
#     Generation Capacity: 30.16 GW
#     Emissions: 39.42 MtCO2e
#     Costs: $230534.5
#     Positive Emissions Deviation: 39.415385900000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7838.55 GWh
#     Generation Capacity: 7.59 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $131786.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1379.91 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.51 MtCO2e
#     Costs: $2986.2
#     Positive Emissions Deviation: 0.5101967000000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8132.43 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.18 MtCO2e
#     Costs: $45104.49
#     Positive Emissions Deviation: 6.179886800000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2030
#   Technology: wind
#     Generation: 80924.64 GWh
#     Generation Capacity: 23.51 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $255911.91
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 13604.24 GWh
#     Generation Capacity: 8.49 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28836.27
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 437950.3 GWh
#     Generation Capacity: 87.42 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5333015.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 82353.64 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2165129.2
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 128115.9 GWh
#     Generation Capacity: 40.33 GW
#     Emissions: 47.4 MtCO2e
#     Costs: $263387.52
#     Positive Emissions Deviation: 47.402513
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 9304.8 GWh
#     Generation Capacity: 8.85 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $137665.08
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 738.59 GWh
#     Generation Capacity: 3.52 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1518.43
#     Positive Emissions Deviation: 0.27290830000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2035
#   Technology: wind
#     Generation: 111348.8 GWh
#     Generation Capacity: 32.47 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $352123.71
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 25234.24 GWh
#     Generation Capacity: 15.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $48138.8
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 438949.6 GWh
#     Generation Capacity: 87.64 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5772801.11
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 90553.33 GWh
#     Generation Capacity: 11.9 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $3356793.92
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 130754.2 GWh
#     Generation Capacity: 44.8 GW
#     Emissions: 48.38 MtCO2e
#     Costs: $255371.19
#     Positive Emissions Deviation: 48.378684
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 17493.74 GWh
#     Generation Capacity: 11.48 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $204468.62
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 498.39 GWh
#     Generation Capacity: 3.02 GW
#     Emissions: 0.18 MtCO2e
#     Costs: $973.39
#     Positive Emissions Deviation: 0.18403429999999998
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2025
#   Technology: wind
#     Generation: 60429.05 GWh
#     Generation Capacity: 18.24 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $187350.99
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 11707.13 GWh
#     Generation Capacity: 7.31 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $27572.19
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 401733.6 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4529626.69
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78278.04 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1459559.81
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 98076.85 GWh
#     Generation Capacity: 31.54 GW
#     Emissions: 36.29 MtCO2e
#     Costs: $212243.45
#     Positive Emissions Deviation: 36.288064500000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 8281.2 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $139228.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1355.5 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.5 MtCO2e
#     Costs: $2933.37
#     Positive Emissions Deviation: 0.501165
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8184.54 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.22 MtCO2e
#     Costs: $45393.5
#     Positive Emissions Deviation: 6.219490400000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2030
#   Technology: wind
#     Generation: 92547.75 GWh
#     Generation Capacity: 25.21 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $292668.24
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 15214.42 GWh
#     Generation Capacity: 9.5 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $32249.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 443103.1 GWh
#     Generation Capacity: 88.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5395762.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 87724.81 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2306340.65
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 122942.64 GWh
#     Generation Capacity: 39.71 GW
#     Emissions: 45.49 MtCO2e
#     Costs: $252752.06
#     Positive Emissions Deviation: 45.4884068
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7526.04 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $111348.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 969.57 GWh
#     Generation Capacity: 3.49 GW
#     Emissions: 0.36 MtCO2e
#     Costs: $1993.29
#     Positive Emissions Deviation: 0.35837090000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2035
#   Technology: wind
#     Generation: 184305.21 GWh
#     Generation Capacity: 50.71 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $582837.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 42161.81 GWh
#     Generation Capacity: 25.05 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $80431.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 465887.5 GWh
#     Generation Capacity: 92.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $6127072.17
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 131692.29 GWh
#     Generation Capacity: 18.56 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4881806.98
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 41866.65 GWh
#     Generation Capacity: 38.39 GW
#     Emissions: 15.49 MtCO2e
#     Costs: $81768.21
#     Positive Emissions Deviation: 15.4902905
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 19716.07 GWh
#     Generation Capacity: 4.03 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $230443.44
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 726.09 GWh
#     Generation Capacity: 2.99 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1418.1
#     Positive Emissions Deviation: 0.2682833
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
# Objective 'Emissions_Deviation' Value: 123.48036019999999
# Objective 'Generation_Deviation' Value: 0.0
# Objective 'Capacity_Deviation' Value: 0.0
# Objective 'Cost_Deviation' Value: 0.0
# Variable Values:
# Generation_Capacity[wind,current,2025] = 17.3
# Generation[wind,current,2025] = 57101.82
# Emissions[wind,current,2025] = 0.0
# Cost[wind,current,2025] = 0.0
# Gen_Emission_Linkage[wind,current,2025] = 0.0
# Cap_Cost_Linkage[wind,current,2025] = 0.0
# Positive_Emissions_Deviation[wind,current,2025] = 0.0
# Negative_Emissions_Deviation[wind,current,2025] = 0.0
# Positive_Cost_Deviation[wind,current,2025] = 0.0
# Negative_Cost_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Generation_Capacity[solar,current,2025] = 7.52
# Generation[solar,current,2025] = 12140.31
# Emissions[solar,current,2025] = 0.0
# Cost[solar,current,2025] = 0.0
# Gen_Emission_Linkage[solar,current,2025] = 0.0
# Cap_Cost_Linkage[solar,current,2025] = 0.0
# Positive_Emissions_Deviation[solar,current,2025] = 0.0
# Negative_Emissions_Deviation[solar,current,2025] = 0.0
# Positive_Cost_Deviation[solar,current,2025] = 0.0
# Negative_Cost_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Generation_Capacity[hydro,current,2025] = 84.91
# Generation[hydro,current,2025] = 403350.8
# Emissions[hydro,current,2025] = 0.0
# Cost[hydro,current,2025] = 0.0
# Gen_Emission_Linkage[hydro,current,2025] = 0.0
# Cap_Cost_Linkage[hydro,current,2025] = 0.0
# Positive_Emissions_Deviation[hydro,current,2025] = 0.0
# Negative_Emissions_Deviation[hydro,current,2025] = 0.0
# Positive_Cost_Deviation[hydro,current,2025] = 0.0
# Negative_Cost_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Generation_Capacity[nuclear,current,2025] = 12.11
# Generation[nuclear,current,2025] = 78631.37
# Emissions[nuclear,current,2025] = 0.0
# Cost[nuclear,current,2025] = 0.0
# Gen_Emission_Linkage[nuclear,current,2025] = 0.0
# Cap_Cost_Linkage[nuclear,current,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2025] = 0.0
# Positive_Cost_Deviation[nuclear,current,2025] = 0.0
# Negative_Cost_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Generation_Capacity[natural_gas,current,2025] = 30.16
# Generation[natural_gas,current,2025] = 106529.07
# Emissions[natural_gas,current,2025] = 39.42
# Cost[natural_gas,current,2025] = 46.1
# Gen_Emission_Linkage[natural_gas,current,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2025] = 21.3
# Positive_Emissions_Deviation[natural_gas,current,2025] = 39.415385900000004
# Negative_Emissions_Deviation[natural_gas,current,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Generation_Capacity[geothermal,current,2025] = 7.59
# Generation[geothermal,current,2025] = 7838.55
# Emissions[geothermal,current,2025] = 0.0
# Cost[geothermal,current,2025] = 46.1
# Gen_Emission_Linkage[geothermal,current,2025] = 0.0
# Cap_Cost_Linkage[geothermal,current,2025] = 2.74
# Positive_Emissions_Deviation[geothermal,current,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2025] = 0.0
# Positive_Cost_Deviation[geothermal,current,2025] = 0.0
# Negative_Cost_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Generation_Capacity[oil,current,2025] = 3.67
# Generation[oil,current,2025] = 1379.91
# Emissions[oil,current,2025] = 0.51
# Cost[oil,current,2025] = 46.1
# Gen_Emission_Linkage[oil,current,2025] = 0.0
# Cap_Cost_Linkage[oil,current,2025] = 21.3
# Positive_Emissions_Deviation[oil,current,2025] = 0.5101967000000001
# Negative_Emissions_Deviation[oil,current,2025] = 0.0
# Positive_Cost_Deviation[oil,current,2025] = 0.0
# Negative_Cost_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Generation_Capacity[coal,current,2025] = 2.93
# Generation[coal,current,2025] = 8132.43
# Emissions[coal,current,2025] = 6.18
# Cost[coal,current,2025] = 46.1
# Gen_Emission_Linkage[coal,current,2025] = 0.0
# Cap_Cost_Linkage[coal,current,2025] = 8.31
# Positive_Emissions_Deviation[coal,current,2025] = 6.179886800000001
# Negative_Emissions_Deviation[coal,current,2025] = 0.0
# Positive_Cost_Deviation[coal,current,2025] = 0.0
# Negative_Cost_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Generation_Capacity[wind,current,2030] = 23.51
# Generation[wind,current,2030] = 80924.64
# Emissions[wind,current,2030] = 0.0
# Cost[wind,current,2030] = 0.0
# Gen_Emission_Linkage[wind,current,2030] = 0.0
# Cap_Cost_Linkage[wind,current,2030] = 0.0
# Positive_Emissions_Deviation[wind,current,2030] = 0.0
# Negative_Emissions_Deviation[wind,current,2030] = 0.0
# Positive_Cost_Deviation[wind,current,2030] = 0.0
# Negative_Cost_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Generation_Capacity[solar,current,2030] = 8.49
# Generation[solar,current,2030] = 13604.24
# Emissions[solar,current,2030] = 0.0
# Cost[solar,current,2030] = 0.0
# Gen_Emission_Linkage[solar,current,2030] = 0.0
# Cap_Cost_Linkage[solar,current,2030] = 0.0
# Positive_Emissions_Deviation[solar,current,2030] = 0.0
# Negative_Emissions_Deviation[solar,current,2030] = 0.0
# Positive_Cost_Deviation[solar,current,2030] = 0.0
# Negative_Cost_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Generation_Capacity[hydro,current,2030] = 87.42
# Generation[hydro,current,2030] = 437950.3
# Emissions[hydro,current,2030] = 0.0
# Cost[hydro,current,2030] = 0.0
# Gen_Emission_Linkage[hydro,current,2030] = 0.0
# Cap_Cost_Linkage[hydro,current,2030] = 0.0
# Positive_Emissions_Deviation[hydro,current,2030] = 0.0
# Negative_Emissions_Deviation[hydro,current,2030] = 0.0
# Positive_Cost_Deviation[hydro,current,2030] = 0.0
# Negative_Cost_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Generation_Capacity[nuclear,current,2030] = 11.11
# Generation[nuclear,current,2030] = 82353.64
# Emissions[nuclear,current,2030] = 0.0
# Cost[nuclear,current,2030] = 0.0
# Gen_Emission_Linkage[nuclear,current,2030] = 0.0
# Cap_Cost_Linkage[nuclear,current,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2030] = 0.0
# Positive_Cost_Deviation[nuclear,current,2030] = 0.0
# Negative_Cost_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Generation_Capacity[natural_gas,current,2030] = 40.33
# Generation[natural_gas,current,2030] = 128115.9
# Emissions[natural_gas,current,2030] = 47.4
# Cost[natural_gas,current,2030] = 47.67
# Gen_Emission_Linkage[natural_gas,current,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2030] = 23.19
# Positive_Emissions_Deviation[natural_gas,current,2030] = 47.402513
# Negative_Emissions_Deviation[natural_gas,current,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Generation_Capacity[geothermal,current,2030] = 8.85
# Generation[geothermal,current,2030] = 9304.8
# Emissions[geothermal,current,2030] = 0.0
# Cost[geothermal,current,2030] = 47.67
# Gen_Emission_Linkage[geothermal,current,2030] = 0.0
# Cap_Cost_Linkage[geothermal,current,2030] = 3.22
# Positive_Emissions_Deviation[geothermal,current,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2030] = 0.0
# Positive_Cost_Deviation[geothermal,current,2030] = 0.0
# Negative_Cost_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Generation_Capacity[oil,current,2030] = 3.52
# Generation[oil,current,2030] = 738.59
# Emissions[oil,current,2030] = 0.27
# Cost[oil,current,2030] = 47.67
# Gen_Emission_Linkage[oil,current,2030] = 0.0
# Cap_Cost_Linkage[oil,current,2030] = 23.19
# Positive_Emissions_Deviation[oil,current,2030] = 0.27290830000000005
# Negative_Emissions_Deviation[oil,current,2030] = 0.0
# Positive_Cost_Deviation[oil,current,2030] = 0.0
# Negative_Cost_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Generation_Capacity[coal,current,2030] = 2.06
# Generation[coal,current,2030] = 0.0
# Emissions[coal,current,2030] = 0.0
# Cost[coal,current,2030] = 47.67
# Gen_Emission_Linkage[coal,current,2030] = 0.0
# Cap_Cost_Linkage[coal,current,2030] = 8.59
# Positive_Emissions_Deviation[coal,current,2030] = 0.0
# Negative_Emissions_Deviation[coal,current,2030] = 0.00076
# Positive_Cost_Deviation[coal,current,2030] = 0.0
# Negative_Cost_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Generation_Capacity[wind,current,2035] = 32.47
# Generation[wind,current,2035] = 111348.8
# Emissions[wind,current,2035] = 0.0
# Cost[wind,current,2035] = 0.0
# Gen_Emission_Linkage[wind,current,2035] = 0.0
# Cap_Cost_Linkage[wind,current,2035] = 0.0
# Positive_Emissions_Deviation[wind,current,2035] = 0.0
# Negative_Emissions_Deviation[wind,current,2035] = 0.0
# Positive_Cost_Deviation[wind,current,2035] = 0.0
# Negative_Cost_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Generation_Capacity[solar,current,2035] = 15.58
# Generation[solar,current,2035] = 25234.24
# Emissions[solar,current,2035] = 0.0
# Cost[solar,current,2035] = 0.0
# Gen_Emission_Linkage[solar,current,2035] = 0.0
# Cap_Cost_Linkage[solar,current,2035] = 0.0
# Positive_Emissions_Deviation[solar,current,2035] = 0.0
# Negative_Emissions_Deviation[solar,current,2035] = 0.0
# Positive_Cost_Deviation[solar,current,2035] = 0.0
# Negative_Cost_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Generation_Capacity[hydro,current,2035] = 87.64
# Generation[hydro,current,2035] = 438949.6
# Emissions[hydro,current,2035] = 0.0
# Cost[hydro,current,2035] = 0.0
# Gen_Emission_Linkage[hydro,current,2035] = 0.0
# Cap_Cost_Linkage[hydro,current,2035] = 0.0
# Positive_Emissions_Deviation[hydro,current,2035] = 0.0
# Negative_Emissions_Deviation[hydro,current,2035] = 0.0
# Positive_Cost_Deviation[hydro,current,2035] = 0.0
# Negative_Cost_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Generation_Capacity[nuclear,current,2035] = 11.9
# Generation[nuclear,current,2035] = 90553.33
# Emissions[nuclear,current,2035] = 0.0
# Cost[nuclear,current,2035] = 0.0
# Gen_Emission_Linkage[nuclear,current,2035] = 0.0
# Cap_Cost_Linkage[nuclear,current,2035] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2035] = 0.0
# Positive_Cost_Deviation[nuclear,current,2035] = 0.0
# Negative_Cost_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Generation_Capacity[natural_gas,current,2035] = 44.8
# Generation[natural_gas,current,2035] = 130754.2
# Emissions[natural_gas,current,2035] = 48.38
# Cost[natural_gas,current,2035] = 48.56
# Gen_Emission_Linkage[natural_gas,current,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2035] = 24.86
# Positive_Emissions_Deviation[natural_gas,current,2035] = 48.378684
# Negative_Emissions_Deviation[natural_gas,current,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Generation_Capacity[geothermal,current,2035] = 11.48
# Generation[geothermal,current,2035] = 17493.74
# Emissions[geothermal,current,2035] = 0.0
# Cost[geothermal,current,2035] = 48.56
# Gen_Emission_Linkage[geothermal,current,2035] = 0.0
# Cap_Cost_Linkage[geothermal,current,2035] = 4.15
# Positive_Emissions_Deviation[geothermal,current,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2035] = 0.0
# Positive_Cost_Deviation[geothermal,current,2035] = 0.0
# Negative_Cost_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Generation_Capacity[oil,current,2035] = 3.02
# Generation[oil,current,2035] = 498.39
# Emissions[oil,current,2035] = 0.18
# Cost[oil,current,2035] = 48.56
# Gen_Emission_Linkage[oil,current,2035] = 0.0
# Cap_Cost_Linkage[oil,current,2035] = 24.86
# Positive_Emissions_Deviation[oil,current,2035] = 0.18403429999999998
# Negative_Emissions_Deviation[oil,current,2035] = 0.0
# Positive_Cost_Deviation[oil,current,2035] = 0.0
# Negative_Cost_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Generation_Capacity[coal,current,2035] = 0.0
# Generation[coal,current,2035] = 0.0
# Emissions[coal,current,2035] = 0.0
# Cost[coal,current,2035] = 48.56
# Gen_Emission_Linkage[coal,current,2035] = 0.0
# Cap_Cost_Linkage[coal,current,2035] = 8.76
# Positive_Emissions_Deviation[coal,current,2035] = 0.0
# Negative_Emissions_Deviation[coal,current,2035] = 0.00076
# Positive_Cost_Deviation[coal,current,2035] = 0.0
# Negative_Cost_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47
# Generation_Capacity[wind,net_zero,2025] = 18.24
# Generation[wind,net_zero,2025] = 60429.05
# Emissions[wind,net_zero,2025] = 0.0
# Cost[wind,net_zero,2025] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2025] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2025] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Generation_Capacity[solar,net_zero,2025] = 7.31
# Generation[solar,net_zero,2025] = 11707.13
# Emissions[solar,net_zero,2025] = 0.0
# Cost[solar,net_zero,2025] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2025] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2025] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Generation_Capacity[hydro,net_zero,2025] = 84.91
# Generation[hydro,net_zero,2025] = 401733.6
# Emissions[hydro,net_zero,2025] = 0.0
# Cost[hydro,net_zero,2025] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2025] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Generation_Capacity[nuclear,net_zero,2025] = 12.11
# Generation[nuclear,net_zero,2025] = 78278.04
# Emissions[nuclear,net_zero,2025] = 0.0
# Cost[nuclear,net_zero,2025] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2025] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Generation_Capacity[natural_gas,net_zero,2025] = 31.54
# Generation[natural_gas,net_zero,2025] = 98076.85
# Emissions[natural_gas,net_zero,2025] = 36.29
# Cost[natural_gas,net_zero,2025] = 43.2
# Gen_Emission_Linkage[natural_gas,net_zero,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[natural_gas,net_zero,2025] = 36.288064500000004
# Negative_Emissions_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Generation_Capacity[geothermal,net_zero,2025] = 2.58
# Generation[geothermal,net_zero,2025] = 8281.2
# Emissions[geothermal,net_zero,2025] = 0.0
# Cost[geothermal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[geothermal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2025] = 2.57
# Positive_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Generation_Capacity[oil,net_zero,2025] = 3.67
# Generation[oil,net_zero,2025] = 1355.5
# Emissions[oil,net_zero,2025] = 0.5
# Cost[oil,net_zero,2025] = 43.2
# Gen_Emission_Linkage[oil,net_zero,2025] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[oil,net_zero,2025] = 0.501165
# Negative_Emissions_Deviation[oil,net_zero,2025] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2025] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Generation_Capacity[coal,net_zero,2025] = 2.93
# Generation[coal,net_zero,2025] = 8184.54
# Emissions[coal,net_zero,2025] = 6.22
# Cost[coal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[coal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2025] = 7.79
# Positive_Emissions_Deviation[coal,net_zero,2025] = 6.219490400000001
# Negative_Emissions_Deviation[coal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[coal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Generation_Capacity[wind,net_zero,2030] = 25.21
# Generation[wind,net_zero,2030] = 92547.75
# Emissions[wind,net_zero,2030] = 0.0
# Cost[wind,net_zero,2030] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2030] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2030] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Generation_Capacity[solar,net_zero,2030] = 9.5
# Generation[solar,net_zero,2030] = 15214.42
# Emissions[solar,net_zero,2030] = 0.0
# Cost[solar,net_zero,2030] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2030] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2030] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Generation_Capacity[hydro,net_zero,2030] = 88.08
# Generation[hydro,net_zero,2030] = 443103.1
# Emissions[hydro,net_zero,2030] = 0.0
# Cost[hydro,net_zero,2030] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2030] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Generation_Capacity[nuclear,net_zero,2030] = 11.11
# Generation[nuclear,net_zero,2030] = 87724.81
# Emissions[nuclear,net_zero,2030] = 0.0
# Cost[nuclear,net_zero,2030] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2030] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Generation_Capacity[natural_gas,net_zero,2030] = 39.71
# Generation[natural_gas,net_zero,2030] = 122942.64
# Emissions[natural_gas,net_zero,2030] = 45.49
# Cost[natural_gas,net_zero,2030] = 45.9
# Gen_Emission_Linkage[natural_gas,net_zero,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[natural_gas,net_zero,2030] = 45.4884068
# Negative_Emissions_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Generation_Capacity[geothermal,net_zero,2030] = 2.58
# Generation[geothermal,net_zero,2030] = 7526.04
# Emissions[geothermal,net_zero,2030] = 0.0
# Cost[geothermal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[geothermal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2030] = 3.1
# Positive_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Generation_Capacity[oil,net_zero,2030] = 3.49
# Generation[oil,net_zero,2030] = 969.57
# Emissions[oil,net_zero,2030] = 0.36
# Cost[oil,net_zero,2030] = 45.9
# Gen_Emission_Linkage[oil,net_zero,2030] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[oil,net_zero,2030] = 0.35837090000000005
# Negative_Emissions_Deviation[oil,net_zero,2030] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2030] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Generation_Capacity[coal,net_zero,2030] = 2.06
# Generation[coal,net_zero,2030] = 0.0
# Emissions[coal,net_zero,2030] = 0.0
# Cost[coal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[coal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2030] = 8.28
# Positive_Emissions_Deviation[coal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2030] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Generation_Capacity[wind,net_zero,2035] = 50.71
# Generation[wind,net_zero,2035] = 184305.21
# Emissions[wind,net_zero,2035] = 0.0
# Cost[wind,net_zero,2035] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2035] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2035] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Generation_Capacity[solar,net_zero,2035] = 25.05
# Generation[solar,net_zero,2035] = 42161.81
# Emissions[solar,net_zero,2035] = 0.0
# Cost[solar,net_zero,2035] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2035] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2035] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Generation_Capacity[hydro,net_zero,2035] = 92.08
# Generation[hydro,net_zero,2035] = 465887.5
# Emissions[hydro,net_zero,2035] = 0.0
# Cost[hydro,net_zero,2035] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2035] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Generation_Capacity[nuclear,net_zero,2035] = 18.56
# Generation[nuclear,net_zero,2035] = 131692.29
# Emissions[nuclear,net_zero,2035] = 0.0
# Cost[nuclear,net_zero,2035] = 15.75
# Gen_Emission_Linkage[nuclear,net_zero,2035] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2035] = 0.42
# Positive_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Generation_Capacity[natural_gas,net_zero,2035] = 38.39
# Generation[natural_gas,net_zero,2035] = 41866.65
# Emissions[natural_gas,net_zero,2035] = 15.49
# Cost[natural_gas,net_zero,2035] = 15.75
# Gen_Emission_Linkage[natural_gas,net_zero,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[natural_gas,net_zero,2035] = 15.4902905
# Negative_Emissions_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Generation_Capacity[geothermal,net_zero,2035] = 4.03
# Generation[geothermal,net_zero,2035] = 19716.07
# Emissions[geothermal,net_zero,2035] = 0.0
# Cost[geothermal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[geothermal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2035] = 1.35
# Positive_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Generation_Capacity[oil,net_zero,2035] = 2.99
# Generation[oil,net_zero,2035] = 726.09
# Emissions[oil,net_zero,2035] = 0.27
# Cost[oil,net_zero,2035] = 15.75
# Gen_Emission_Linkage[oil,net_zero,2035] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[oil,net_zero,2035] = 0.2682833
# Negative_Emissions_Deviation[oil,net_zero,2035] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2035] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Generation_Capacity[coal,net_zero,2035] = 0.0
# Generation[coal,net_zero,2035] = 0.0
# Emissions[coal,net_zero,2035] = 0.0
# Cost[coal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[coal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2035] = 2.84
# Positive_Emissions_Deviation[coal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2035] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47

# %% [markdown]
# ## Optimist Model

# %%
import pandas as pd
import gurobipy as gb
from gurobipy import *

# Define the probabilities of scenarios
Ps = {
    "current": 0.35,
    "net_zero": 0.65,
}

# Define Sets
S = ["current", "net_zero"]
T = [2025, 2030, 2035]
G = ["wind", "solar", "hydro", "nuclear", "natural_gas", "geothermal", "oil", "coal"]

# Read each sheet into a DataFrame
df_Dst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Electricity Demand')
df_Lgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Output Targets')
df_Ugst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Capacity Targets')
df_Eg = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Factor')
df_Cgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Cost')
df_Bst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Cap')
df_Kst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Capital Expenditure Budget')

df_dev_e = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_E')
df_dev_g = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_G')
df_dev_q = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_Q')
df_dev_c = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_C')

# Convert DataFrames to dictionaries
Dst = df_Dst.set_index(['Scenario', 'Year']).to_dict()['Electricity Demand (GWh)']
Lgst = df_Lgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Output Targets (GWh)']
Ugst = df_Ugst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Capacity Targets (GW)']
Cgst = df_Cgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Cost (Millions$/GW)']
Bst = df_Bst.set_index(['Technology','Scenario', 'Year']).to_dict()['Emissions Cap (MtCO2)']
Eg = df_Eg.set_index(['Technology','Scenario','Year']).to_dict()['Emissions Factor (MtCO2/GWh)']
Kst = {scenario: df_Kst[df_Kst['Scenario'] == scenario].set_index('Year')['Value'].to_dict() for scenario in df_Kst['Scenario'].unique()}

dev_e_plus = df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_g_plus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_q_plus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_c_plus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% UB']

dev_e_minus= df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_g_minus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_q_minus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_c_minus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% LB']

# Create Model
m = Model("CanadaEnergyModel")

# Decision Variables
X = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation_Capacity")
Y = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation")
Z = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Emissions")
C = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cost")
W = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Gen_Emission_Linkage")
V = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cap_Cost_Linkage")

# Deviation Variables
et_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Emissions_Deviation")
et_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Emissions_Deviation")
ct_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Cost_Deviation")
ct_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Cost_Deviation")
gt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Deviation")
gt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Deviation")
qt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Capacity_Deviation")
qt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Capacity_Deviation")
# Set upper bounds for positive deviation variables based on data from Excel
for g in G:
    for s in S:
        for t in T:
            et_plus[g, s, t].ub = dev_e_plus.get((g, s, t), 0)
            ct_plus[g, s, t].ub = dev_c_plus.get((g, s, t), 0)
            gt_plus[g, s, t].ub = dev_g_plus.get((g, s, t), 0)
            qt_plus[g,s,t].ub = dev_q_plus.get((g,s,t), 0)


#Set upper bounds for negative deviation variables based on data from Excel
for g in G:
   for s in S:
        for t in T:
            et_minus[g,s,t].ub = dev_e_minus.get((g,s,t), 0)
            ct_minus[g,s,t].ub = dev_c_minus.get((g,s,t), 0)
            gt_minus[g,s,t].ub = dev_g_minus.get((g,s,t), 0)
            qt_minus[g,s,t].ub = dev_q_minus.get((g,s,t), 0)
            

# Constraints

# Probability sum constraint
probability_sum_constraint = m.addConstr((sum(Ps[s] for s in S) == 1), name="Probability_Sum")

# Electricity demand constraints
demand_constraints = {}
for s in S:
    for t in T:
        demand_constraints[s, t] = m.addConstr(
            sum(Y[g, s, t] for g in G) <= Dst[(s, t)],
            name=f"Demand_{s}_{t}",
        )

# Generation capacity limit constraints
capacity_limit_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_limit_constraints[g, s, t] = m.addConstr(
                Y[g, s, t] <= X[g, s, t] * 8760 * 1,
                name=f"Capacity_Limit_{g}_{s}_{t}",
            )

# Emission constraints
emission_constraints = {}
for s in S:
    for t in T:
        emission_constraints[s, t] = m.addConstr(
            sum(Z[g, s, t] for g in G) <= (Bst[(g,s, t)] + et_plus.sum('*', s, t) - et_minus.sum('*', s, t)),
            name=f"Emission_{g}_{s}_{t}",
        )

# Capital expenditure constraints
for s in S:
    for t in T:
        m.addConstr(
            sum(C[g, s, t] for g in G) <= Kst[s][t] + ct_plus.sum('*', s, t) - ct_minus.sum('*', s, t),
            name=f"CapEx_{s}_{t}",
        )

# Generation target constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] >= Lgst[(g, s, t)] - gt_plus[g, s, t] + gt_minus[g, s, t],
                name=f"Generation_Target_{g}_{s}_{t}",
            )

# Generation capacity target constraints
capacity_target_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_target_constraints[g, s, t] = m.addConstr(
                X[g, s, t] >= Ugst[(g, s, t)] - qt_plus[g, s, t] + qt_minus[g, s, t],
                name=f"Capacity_Target_{g}_{s}_{t}",
            )


# Define the emissions linking constraints dictionary
emissions_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            emissions_linking_constraints[g, s, t] = m.addConstr(
                Z[g, s, t] == Y[g, s, t] * Eg[g, s, t],
                name=f"Emission_Linking_{g}_{s}_{t}",
            )


# Cost linking constraints
cost_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            cost_linking_constraints[g, s, t] = m.addConstr(
                C[g, s, t] == V[g, s, t] * Cgst[(g, s, t)],
                name=f"Cost_Linking_{g}_{s}_{t}",
            )

# Emissions goal achievement constraints
for g in G:
    for s in S:
       for t in T:
            m.addConstr(
                Z[g, s, t] - et_plus[g, s, t] + et_minus[g, s, t]
               == Eg[g, s, t],
               name=f"Emissions_Goal_{g}_{s}_{t}",
            )

# Cost goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                C[g, s, t] - ct_plus[g, s, t] + ct_minus[g, s, t]
                == Bst[g,s, t],
                name=f"Cost_Goal_{g}_{s}_{t}",
            )

# Generation goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] - gt_plus[g, s, t] + gt_minus[g, s, t]
                == Lgst[g, s, t],
                name=f"Generation_Goal_{g}_{s}_{t}",
            )

# Generation capacity goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                X[g, s, t] - qt_plus[g, s, t] + qt_minus[g, s, t]
                == Ugst[g, s, t],
                name=f"Capacity_Goal_{g}_{s}_{t}",
            )

# Define the multiple objectives
objectives = {
    "Emissions_Deviation": {"expr": LinExpr(), "priority": 3},
    "Generation_Deviation": {"expr": LinExpr(), "priority": 2},
    "Capacity_Deviation": {"expr": LinExpr(), "priority": 1},
    "Cost_Deviation": {"expr": LinExpr(), "priority": 0},
}

# Loop through scenarios
for s in S:
  # Loop through time periods
  for t in T:
    # Loop through generation technologies
    for g in G:
      # Objective expressions with g, s, t indexing
      objectives["Emissions_Deviation"]["expr"] += Ps[s] * (et_plus[g,s,t] + et_minus[g,s,t])
      objectives["Generation_Deviation"]["expr"] += Ps[s] * (gt_plus[g,s,t] + gt_minus[g,s,t])
      objectives["Capacity_Deviation"]["expr"] += Ps[s] * (qt_plus[g,s,t] + qt_minus[g,s,t])
      objectives["Cost_Deviation"]["expr"] += Ps[s] * (ct_plus[g,s,t] + ct_minus[g,s,t])

# Set the objectives using setObjectiveN
for i, (obj_name, obj_data) in enumerate(objectives.items()):
  m.setObjectiveN(obj_data["expr"], index=i, priority=obj_data["priority"], name=obj_name)

# Optimize the model
m.optimize()

# Rounding function
def round_to_2(val):
    return round(val, 2)


if m.status == GRB.OPTIMAL:
    print("Optimal Solution Found. Printing Values:")

    for s in S:
        for t in T:
            print(f"\nScenario: {s}, Time Period: {t}")
            for g in G:
                print(f"  Technology: {g}")
                generation = Y[g, s, t].x  # Use actual generation instead of capacity
                cost_per_gw = Cgst[(g, s, t)]
                total_cost = generation * cost_per_gw
                print(f"    Generation: {round_to_2(generation)} GWh")
                print(f"    Generation Capacity: {round_to_2(X[g, s, t].x)} GW")
                print(f"    Emissions: {round_to_2(Z[g, s, t].x)} MtCO2e")
                print(f"    Costs: ${round_to_2(total_cost)}")
                # Adding unrounded positive and negative deviations
                print(f"    Positive Emissions Deviation: {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"    Negative Emissions Deviation: {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")
                print(f"    Positive Cost Deviation: {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")
                print(f"    Negative Cost Deviation: {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Deviation: {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Deviation: {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Capacity Deviation: {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Capacity Deviation: {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

if m.status == GRB.OPTIMAL:
    
        # Retrieve and print the values for each objective
    for i, obj_name in enumerate(objectives.keys()):
        m.setParam(GRB.Param.ObjNumber, i)
        obj_value = m.ObjNVal
        print(f"Objective '{obj_name}' Value: {obj_value}")

    # Print rounded variable values
    print("Variable Values:")
    for s in S:
        for t in T:
            for g in G:

                # Generation capacity
                rounded_X = round_to_2(X[g, s, t].x) if X[g, s, t] is not None else 0
                print(f"{X[g, s, t].varName} = {rounded_X}")

                # Generation
                rounded_Y = round_to_2(Y[g, s, t].x) if Y[g, s, t] is not None else 0
                print(f"{Y[g, s, t].varName} = {rounded_Y}")

                # Emissions
                rounded_Z = round_to_2(Z[g, s, t].x) if Z[g, s, t] is not None else 0
                print(f"{Z[g, s, t].varName} = {rounded_Z}")

                # Costs
                rounded_C = round_to_2(C[g, s, t].x) if C[g, s, t] is not None else 0
                print(f"{C[g, s, t].varName} = {rounded_C}")

                # Emission linkage
                rounded_W = round_to_2(W[g, s, t].x) if W[g, s, t] is not None else 0
                print(f"{W[g, s, t].varName} = {rounded_W}")

                # Cost linkage
                rounded_V = round_to_2(V[g, s, t].x) if V[g, s, t] is not None else 0
                print(f"{V[g, s, t].varName} = {rounded_V}")

                # Emissions deviation
                print(f"{et_plus[g, s, t].varName} = {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"{et_minus[g, s, t].varName} = {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")

                # Cost deviation
                print(f"{ct_plus[g, s, t].varName} = {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")

                print(f"{ct_minus[g, s, t].varName} = {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")

                # Generation deviation
                print(f"{gt_plus[g, s, t].varName} = {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")

                print(f"{gt_minus[g, s, t].varName} = {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")

                # Capacity deviation
                print(f"{qt_plus[g, s, t].varName} = {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")

                print(f"{qt_minus[g, s, t].varName} = {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

        # Print totals for each decision variable in each scenario and time period
        for s in S:
            for t in T:
                total_gen_st = sum(Y[g, s, t].x for g in G)
                total_cap_st = sum(X[g, s, t].x for g in G)
                total_emission_st = sum(Z[g, s, t].x for g in G)
                total_cost_st = sum(C[g, s, t].x for g in G)

                print("--------------------------------------------------")
                print(f"Scenario: {s}, Time Period: {t}")
                print(f"Total Generation (GWh): {round_to_2(total_gen_st)}")
                print(f"Total Capacity (GW): {round_to_2(total_cap_st)}")
                print(f"Total Emissions (MtCO2e): {round_to_2(total_emission_st)}")
                print(f"Total Cost (Million CAD): ${round_to_2(total_cost_st)}")
                print("--------------------------------------------------\n")

        # Sum decision variables over G, S, and T dimensions for overall total
        total_gen = sum(Y[g, s, t].x for g in G for s in S for t in T)
        total_cap = sum(X[g, s, t].x for g in G for s in S for t in T)
        total_emission = sum(Z[g, s, t].x for g in G for s in S for t in T)
        total_cost = sum(C[g, s, t].x for g in G for s in S for t in T)

        print("\nOverall Total Across All Scenarios and Time Periods:")
        print(f"Total Generation (GWh): {round_to_2(total_gen)}")
        print(f"Total Capacity (GW): {round_to_2(total_cap)}")
        print(f"Total Emissions (MtCO2e): {round_to_2(total_emission)}")
        print(f"Total Cost (Million CAD): ${round_to_2(total_cost)}")
        
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 451 rows, 672 columns and 1458 nonzeros
# Model fingerprint: 0x57a80869
# Variable types: 672 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 9e+03]
#   Objective range  [3e-01, 7e-01]
#   Bounds range     [2e+00, 5e+05]
#   RHS range        [4e-04, 9e+05]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 4 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 245 rows and 254 columns
# Presolved: 206 rows and 418 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (Emissions_Deviatio) ...
# ---------------------------------------------------------------------------
#
# Presolve removed 206 rows and 418 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1782093e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.178209296e+02
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Generation_Deviati) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4384289e+05   0.000000e+00   5.060000e+01      0s
#       22    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.06 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 (Capacity_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2742422e+02   0.000000e+00   2.437000e+03      0s
#       46    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 46 iterations and 0.08 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 (Cost_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4785939e+02   0.000000e+00   4.200000e+01      0s
#       24    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.10 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.10 seconds (0.00 work units), solution count 4
#
# Optimal Solution Found. Printing Values:
#
# Scenario: current, Time Period: 2025
#   Technology: wind
#     Generation: 57101.82 GWh
#     Generation Capacity: 17.3 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $177035.43
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 12140.31 GWh
#     Generation Capacity: 7.52 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28592.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 403350.8 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4547860.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78631.37 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1466147.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 106529.07 GWh
#     Generation Capacity: 30.16 GW
#     Emissions: 39.42 MtCO2e
#     Costs: $230534.5
#     Positive Emissions Deviation: 39.415385900000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7838.55 GWh
#     Generation Capacity: 7.59 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $131786.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1379.91 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.51 MtCO2e
#     Costs: $2986.2
#     Positive Emissions Deviation: 0.5101967000000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8132.43 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.18 MtCO2e
#     Costs: $45104.49
#     Positive Emissions Deviation: 6.179886800000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2030
#   Technology: wind
#     Generation: 80924.64 GWh
#     Generation Capacity: 23.51 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $255911.91
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 13604.24 GWh
#     Generation Capacity: 8.49 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28836.27
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 437950.3 GWh
#     Generation Capacity: 87.42 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5333015.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 82353.64 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2165129.2
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 128115.9 GWh
#     Generation Capacity: 40.33 GW
#     Emissions: 47.4 MtCO2e
#     Costs: $263387.52
#     Positive Emissions Deviation: 47.402513
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 9304.8 GWh
#     Generation Capacity: 8.85 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $137665.08
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 738.59 GWh
#     Generation Capacity: 3.52 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1518.43
#     Positive Emissions Deviation: 0.27290830000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2035
#   Technology: wind
#     Generation: 111348.8 GWh
#     Generation Capacity: 32.47 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $352123.71
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 25234.24 GWh
#     Generation Capacity: 15.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $48138.8
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 438949.6 GWh
#     Generation Capacity: 87.64 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5772801.11
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 90553.33 GWh
#     Generation Capacity: 11.9 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $3356793.92
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 130754.2 GWh
#     Generation Capacity: 44.8 GW
#     Emissions: 48.38 MtCO2e
#     Costs: $255371.19
#     Positive Emissions Deviation: 48.378684
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 17493.74 GWh
#     Generation Capacity: 11.48 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $204468.62
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 498.39 GWh
#     Generation Capacity: 3.02 GW
#     Emissions: 0.18 MtCO2e
#     Costs: $973.39
#     Positive Emissions Deviation: 0.18403429999999998
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2025
#   Technology: wind
#     Generation: 60429.05 GWh
#     Generation Capacity: 18.24 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $187350.99
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 11707.13 GWh
#     Generation Capacity: 7.31 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $27572.19
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 401733.6 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4529626.69
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78278.04 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1459559.81
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 98076.85 GWh
#     Generation Capacity: 31.54 GW
#     Emissions: 36.29 MtCO2e
#     Costs: $212243.45
#     Positive Emissions Deviation: 36.288064500000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 8281.2 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $139228.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1355.5 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.5 MtCO2e
#     Costs: $2933.37
#     Positive Emissions Deviation: 0.501165
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8184.54 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.22 MtCO2e
#     Costs: $45393.5
#     Positive Emissions Deviation: 6.219490400000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2030
#   Technology: wind
#     Generation: 92547.75 GWh
#     Generation Capacity: 25.21 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $292668.24
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 15214.42 GWh
#     Generation Capacity: 9.5 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $32249.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 443103.1 GWh
#     Generation Capacity: 88.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5395762.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 87724.81 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2306340.65
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 122942.64 GWh
#     Generation Capacity: 39.71 GW
#     Emissions: 45.49 MtCO2e
#     Costs: $252752.06
#     Positive Emissions Deviation: 45.4884068
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7526.04 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $111348.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 969.57 GWh
#     Generation Capacity: 3.49 GW
#     Emissions: 0.36 MtCO2e
#     Costs: $1993.29
#     Positive Emissions Deviation: 0.35837090000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2035
#   Technology: wind
#     Generation: 184305.21 GWh
#     Generation Capacity: 50.71 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $582837.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 42161.81 GWh
#     Generation Capacity: 25.05 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $80431.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 465887.5 GWh
#     Generation Capacity: 92.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $6127072.17
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 131692.29 GWh
#     Generation Capacity: 18.56 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4881806.98
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 41866.65 GWh
#     Generation Capacity: 38.39 GW
#     Emissions: 15.49 MtCO2e
#     Costs: $81768.21
#     Positive Emissions Deviation: 15.4902905
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 19716.07 GWh
#     Generation Capacity: 4.03 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $230443.44
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 726.09 GWh
#     Generation Capacity: 2.99 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1418.1
#     Positive Emissions Deviation: 0.2682833
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
# Objective 'Emissions_Deviation' Value: 117.82092956000001
# Objective 'Generation_Deviation' Value: 0.0
# Objective 'Capacity_Deviation' Value: 0.0
# Objective 'Cost_Deviation' Value: 0.0
# Variable Values:
# Generation_Capacity[wind,current,2025] = 17.3
# Generation[wind,current,2025] = 57101.82
# Emissions[wind,current,2025] = 0.0
# Cost[wind,current,2025] = 0.0
# Gen_Emission_Linkage[wind,current,2025] = 0.0
# Cap_Cost_Linkage[wind,current,2025] = 0.0
# Positive_Emissions_Deviation[wind,current,2025] = 0.0
# Negative_Emissions_Deviation[wind,current,2025] = 0.0
# Positive_Cost_Deviation[wind,current,2025] = 0.0
# Negative_Cost_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Generation_Capacity[solar,current,2025] = 7.52
# Generation[solar,current,2025] = 12140.31
# Emissions[solar,current,2025] = 0.0
# Cost[solar,current,2025] = 0.0
# Gen_Emission_Linkage[solar,current,2025] = 0.0
# Cap_Cost_Linkage[solar,current,2025] = 0.0
# Positive_Emissions_Deviation[solar,current,2025] = 0.0
# Negative_Emissions_Deviation[solar,current,2025] = 0.0
# Positive_Cost_Deviation[solar,current,2025] = 0.0
# Negative_Cost_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Generation_Capacity[hydro,current,2025] = 84.91
# Generation[hydro,current,2025] = 403350.8
# Emissions[hydro,current,2025] = 0.0
# Cost[hydro,current,2025] = 0.0
# Gen_Emission_Linkage[hydro,current,2025] = 0.0
# Cap_Cost_Linkage[hydro,current,2025] = 0.0
# Positive_Emissions_Deviation[hydro,current,2025] = 0.0
# Negative_Emissions_Deviation[hydro,current,2025] = 0.0
# Positive_Cost_Deviation[hydro,current,2025] = 0.0
# Negative_Cost_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Generation_Capacity[nuclear,current,2025] = 12.11
# Generation[nuclear,current,2025] = 78631.37
# Emissions[nuclear,current,2025] = 0.0
# Cost[nuclear,current,2025] = 0.0
# Gen_Emission_Linkage[nuclear,current,2025] = 0.0
# Cap_Cost_Linkage[nuclear,current,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2025] = 0.0
# Positive_Cost_Deviation[nuclear,current,2025] = 0.0
# Negative_Cost_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Generation_Capacity[natural_gas,current,2025] = 30.16
# Generation[natural_gas,current,2025] = 106529.07
# Emissions[natural_gas,current,2025] = 39.42
# Cost[natural_gas,current,2025] = 46.1
# Gen_Emission_Linkage[natural_gas,current,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2025] = 21.3
# Positive_Emissions_Deviation[natural_gas,current,2025] = 39.415385900000004
# Negative_Emissions_Deviation[natural_gas,current,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Generation_Capacity[geothermal,current,2025] = 7.59
# Generation[geothermal,current,2025] = 7838.55
# Emissions[geothermal,current,2025] = 0.0
# Cost[geothermal,current,2025] = 46.1
# Gen_Emission_Linkage[geothermal,current,2025] = 0.0
# Cap_Cost_Linkage[geothermal,current,2025] = 2.74
# Positive_Emissions_Deviation[geothermal,current,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2025] = 0.0
# Positive_Cost_Deviation[geothermal,current,2025] = 0.0
# Negative_Cost_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Generation_Capacity[oil,current,2025] = 3.67
# Generation[oil,current,2025] = 1379.91
# Emissions[oil,current,2025] = 0.51
# Cost[oil,current,2025] = 46.1
# Gen_Emission_Linkage[oil,current,2025] = 0.0
# Cap_Cost_Linkage[oil,current,2025] = 21.3
# Positive_Emissions_Deviation[oil,current,2025] = 0.5101967000000001
# Negative_Emissions_Deviation[oil,current,2025] = 0.0
# Positive_Cost_Deviation[oil,current,2025] = 0.0
# Negative_Cost_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Generation_Capacity[coal,current,2025] = 2.93
# Generation[coal,current,2025] = 8132.43
# Emissions[coal,current,2025] = 6.18
# Cost[coal,current,2025] = 46.1
# Gen_Emission_Linkage[coal,current,2025] = 0.0
# Cap_Cost_Linkage[coal,current,2025] = 8.31
# Positive_Emissions_Deviation[coal,current,2025] = 6.179886800000001
# Negative_Emissions_Deviation[coal,current,2025] = 0.0
# Positive_Cost_Deviation[coal,current,2025] = 0.0
# Negative_Cost_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Generation_Capacity[wind,current,2030] = 23.51
# Generation[wind,current,2030] = 80924.64
# Emissions[wind,current,2030] = 0.0
# Cost[wind,current,2030] = 0.0
# Gen_Emission_Linkage[wind,current,2030] = 0.0
# Cap_Cost_Linkage[wind,current,2030] = 0.0
# Positive_Emissions_Deviation[wind,current,2030] = 0.0
# Negative_Emissions_Deviation[wind,current,2030] = 0.0
# Positive_Cost_Deviation[wind,current,2030] = 0.0
# Negative_Cost_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Generation_Capacity[solar,current,2030] = 8.49
# Generation[solar,current,2030] = 13604.24
# Emissions[solar,current,2030] = 0.0
# Cost[solar,current,2030] = 0.0
# Gen_Emission_Linkage[solar,current,2030] = 0.0
# Cap_Cost_Linkage[solar,current,2030] = 0.0
# Positive_Emissions_Deviation[solar,current,2030] = 0.0
# Negative_Emissions_Deviation[solar,current,2030] = 0.0
# Positive_Cost_Deviation[solar,current,2030] = 0.0
# Negative_Cost_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Generation_Capacity[hydro,current,2030] = 87.42
# Generation[hydro,current,2030] = 437950.3
# Emissions[hydro,current,2030] = 0.0
# Cost[hydro,current,2030] = 0.0
# Gen_Emission_Linkage[hydro,current,2030] = 0.0
# Cap_Cost_Linkage[hydro,current,2030] = 0.0
# Positive_Emissions_Deviation[hydro,current,2030] = 0.0
# Negative_Emissions_Deviation[hydro,current,2030] = 0.0
# Positive_Cost_Deviation[hydro,current,2030] = 0.0
# Negative_Cost_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Generation_Capacity[nuclear,current,2030] = 11.11
# Generation[nuclear,current,2030] = 82353.64
# Emissions[nuclear,current,2030] = 0.0
# Cost[nuclear,current,2030] = 0.0
# Gen_Emission_Linkage[nuclear,current,2030] = 0.0
# Cap_Cost_Linkage[nuclear,current,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2030] = 0.0
# Positive_Cost_Deviation[nuclear,current,2030] = 0.0
# Negative_Cost_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Generation_Capacity[natural_gas,current,2030] = 40.33
# Generation[natural_gas,current,2030] = 128115.9
# Emissions[natural_gas,current,2030] = 47.4
# Cost[natural_gas,current,2030] = 47.67
# Gen_Emission_Linkage[natural_gas,current,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2030] = 23.19
# Positive_Emissions_Deviation[natural_gas,current,2030] = 47.402513
# Negative_Emissions_Deviation[natural_gas,current,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Generation_Capacity[geothermal,current,2030] = 8.85
# Generation[geothermal,current,2030] = 9304.8
# Emissions[geothermal,current,2030] = 0.0
# Cost[geothermal,current,2030] = 47.67
# Gen_Emission_Linkage[geothermal,current,2030] = 0.0
# Cap_Cost_Linkage[geothermal,current,2030] = 3.22
# Positive_Emissions_Deviation[geothermal,current,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2030] = 0.0
# Positive_Cost_Deviation[geothermal,current,2030] = 0.0
# Negative_Cost_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Generation_Capacity[oil,current,2030] = 3.52
# Generation[oil,current,2030] = 738.59
# Emissions[oil,current,2030] = 0.27
# Cost[oil,current,2030] = 47.67
# Gen_Emission_Linkage[oil,current,2030] = 0.0
# Cap_Cost_Linkage[oil,current,2030] = 23.19
# Positive_Emissions_Deviation[oil,current,2030] = 0.27290830000000005
# Negative_Emissions_Deviation[oil,current,2030] = 0.0
# Positive_Cost_Deviation[oil,current,2030] = 0.0
# Negative_Cost_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Generation_Capacity[coal,current,2030] = 2.06
# Generation[coal,current,2030] = 0.0
# Emissions[coal,current,2030] = 0.0
# Cost[coal,current,2030] = 47.67
# Gen_Emission_Linkage[coal,current,2030] = 0.0
# Cap_Cost_Linkage[coal,current,2030] = 8.59
# Positive_Emissions_Deviation[coal,current,2030] = 0.0
# Negative_Emissions_Deviation[coal,current,2030] = 0.00076
# Positive_Cost_Deviation[coal,current,2030] = 0.0
# Negative_Cost_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Generation_Capacity[wind,current,2035] = 32.47
# Generation[wind,current,2035] = 111348.8
# Emissions[wind,current,2035] = 0.0
# Cost[wind,current,2035] = 0.0
# Gen_Emission_Linkage[wind,current,2035] = 0.0
# Cap_Cost_Linkage[wind,current,2035] = 0.0
# Positive_Emissions_Deviation[wind,current,2035] = 0.0
# Negative_Emissions_Deviation[wind,current,2035] = 0.0
# Positive_Cost_Deviation[wind,current,2035] = 0.0
# Negative_Cost_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Generation_Capacity[solar,current,2035] = 15.58
# Generation[solar,current,2035] = 25234.24
# Emissions[solar,current,2035] = 0.0
# Cost[solar,current,2035] = 0.0
# Gen_Emission_Linkage[solar,current,2035] = 0.0
# Cap_Cost_Linkage[solar,current,2035] = 0.0
# Positive_Emissions_Deviation[solar,current,2035] = 0.0
# Negative_Emissions_Deviation[solar,current,2035] = 0.0
# Positive_Cost_Deviation[solar,current,2035] = 0.0
# Negative_Cost_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Generation_Capacity[hydro,current,2035] = 87.64
# Generation[hydro,current,2035] = 438949.6
# Emissions[hydro,current,2035] = 0.0
# Cost[hydro,current,2035] = 0.0
# Gen_Emission_Linkage[hydro,current,2035] = 0.0
# Cap_Cost_Linkage[hydro,current,2035] = 0.0
# Positive_Emissions_Deviation[hydro,current,2035] = 0.0
# Negative_Emissions_Deviation[hydro,current,2035] = 0.0
# Positive_Cost_Deviation[hydro,current,2035] = 0.0
# Negative_Cost_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Generation_Capacity[nuclear,current,2035] = 11.9
# Generation[nuclear,current,2035] = 90553.33
# Emissions[nuclear,current,2035] = 0.0
# Cost[nuclear,current,2035] = 0.0
# Gen_Emission_Linkage[nuclear,current,2035] = 0.0
# Cap_Cost_Linkage[nuclear,current,2035] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2035] = 0.0
# Positive_Cost_Deviation[nuclear,current,2035] = 0.0
# Negative_Cost_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Generation_Capacity[natural_gas,current,2035] = 44.8
# Generation[natural_gas,current,2035] = 130754.2
# Emissions[natural_gas,current,2035] = 48.38
# Cost[natural_gas,current,2035] = 48.56
# Gen_Emission_Linkage[natural_gas,current,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2035] = 24.86
# Positive_Emissions_Deviation[natural_gas,current,2035] = 48.378684
# Negative_Emissions_Deviation[natural_gas,current,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Generation_Capacity[geothermal,current,2035] = 11.48
# Generation[geothermal,current,2035] = 17493.74
# Emissions[geothermal,current,2035] = 0.0
# Cost[geothermal,current,2035] = 48.56
# Gen_Emission_Linkage[geothermal,current,2035] = 0.0
# Cap_Cost_Linkage[geothermal,current,2035] = 4.15
# Positive_Emissions_Deviation[geothermal,current,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2035] = 0.0
# Positive_Cost_Deviation[geothermal,current,2035] = 0.0
# Negative_Cost_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Generation_Capacity[oil,current,2035] = 3.02
# Generation[oil,current,2035] = 498.39
# Emissions[oil,current,2035] = 0.18
# Cost[oil,current,2035] = 48.56
# Gen_Emission_Linkage[oil,current,2035] = 0.0
# Cap_Cost_Linkage[oil,current,2035] = 24.86
# Positive_Emissions_Deviation[oil,current,2035] = 0.18403429999999998
# Negative_Emissions_Deviation[oil,current,2035] = 0.0
# Positive_Cost_Deviation[oil,current,2035] = 0.0
# Negative_Cost_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Generation_Capacity[coal,current,2035] = 0.0
# Generation[coal,current,2035] = 0.0
# Emissions[coal,current,2035] = 0.0
# Cost[coal,current,2035] = 48.56
# Gen_Emission_Linkage[coal,current,2035] = 0.0
# Cap_Cost_Linkage[coal,current,2035] = 8.76
# Positive_Emissions_Deviation[coal,current,2035] = 0.0
# Negative_Emissions_Deviation[coal,current,2035] = 0.00076
# Positive_Cost_Deviation[coal,current,2035] = 0.0
# Negative_Cost_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47
# Generation_Capacity[wind,net_zero,2025] = 18.24
# Generation[wind,net_zero,2025] = 60429.05
# Emissions[wind,net_zero,2025] = 0.0
# Cost[wind,net_zero,2025] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2025] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2025] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Generation_Capacity[solar,net_zero,2025] = 7.31
# Generation[solar,net_zero,2025] = 11707.13
# Emissions[solar,net_zero,2025] = 0.0
# Cost[solar,net_zero,2025] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2025] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2025] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Generation_Capacity[hydro,net_zero,2025] = 84.91
# Generation[hydro,net_zero,2025] = 401733.6
# Emissions[hydro,net_zero,2025] = 0.0
# Cost[hydro,net_zero,2025] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2025] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Generation_Capacity[nuclear,net_zero,2025] = 12.11
# Generation[nuclear,net_zero,2025] = 78278.04
# Emissions[nuclear,net_zero,2025] = 0.0
# Cost[nuclear,net_zero,2025] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2025] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Generation_Capacity[natural_gas,net_zero,2025] = 31.54
# Generation[natural_gas,net_zero,2025] = 98076.85
# Emissions[natural_gas,net_zero,2025] = 36.29
# Cost[natural_gas,net_zero,2025] = 43.2
# Gen_Emission_Linkage[natural_gas,net_zero,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[natural_gas,net_zero,2025] = 36.288064500000004
# Negative_Emissions_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Generation_Capacity[geothermal,net_zero,2025] = 2.58
# Generation[geothermal,net_zero,2025] = 8281.2
# Emissions[geothermal,net_zero,2025] = 0.0
# Cost[geothermal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[geothermal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2025] = 2.57
# Positive_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Generation_Capacity[oil,net_zero,2025] = 3.67
# Generation[oil,net_zero,2025] = 1355.5
# Emissions[oil,net_zero,2025] = 0.5
# Cost[oil,net_zero,2025] = 43.2
# Gen_Emission_Linkage[oil,net_zero,2025] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[oil,net_zero,2025] = 0.501165
# Negative_Emissions_Deviation[oil,net_zero,2025] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2025] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Generation_Capacity[coal,net_zero,2025] = 2.93
# Generation[coal,net_zero,2025] = 8184.54
# Emissions[coal,net_zero,2025] = 6.22
# Cost[coal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[coal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2025] = 7.79
# Positive_Emissions_Deviation[coal,net_zero,2025] = 6.219490400000001
# Negative_Emissions_Deviation[coal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[coal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Generation_Capacity[wind,net_zero,2030] = 25.21
# Generation[wind,net_zero,2030] = 92547.75
# Emissions[wind,net_zero,2030] = 0.0
# Cost[wind,net_zero,2030] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2030] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2030] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Generation_Capacity[solar,net_zero,2030] = 9.5
# Generation[solar,net_zero,2030] = 15214.42
# Emissions[solar,net_zero,2030] = 0.0
# Cost[solar,net_zero,2030] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2030] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2030] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Generation_Capacity[hydro,net_zero,2030] = 88.08
# Generation[hydro,net_zero,2030] = 443103.1
# Emissions[hydro,net_zero,2030] = 0.0
# Cost[hydro,net_zero,2030] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2030] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Generation_Capacity[nuclear,net_zero,2030] = 11.11
# Generation[nuclear,net_zero,2030] = 87724.81
# Emissions[nuclear,net_zero,2030] = 0.0
# Cost[nuclear,net_zero,2030] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2030] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Generation_Capacity[natural_gas,net_zero,2030] = 39.71
# Generation[natural_gas,net_zero,2030] = 122942.64
# Emissions[natural_gas,net_zero,2030] = 45.49
# Cost[natural_gas,net_zero,2030] = 45.9
# Gen_Emission_Linkage[natural_gas,net_zero,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[natural_gas,net_zero,2030] = 45.4884068
# Negative_Emissions_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Generation_Capacity[geothermal,net_zero,2030] = 2.58
# Generation[geothermal,net_zero,2030] = 7526.04
# Emissions[geothermal,net_zero,2030] = 0.0
# Cost[geothermal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[geothermal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2030] = 3.1
# Positive_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Generation_Capacity[oil,net_zero,2030] = 3.49
# Generation[oil,net_zero,2030] = 969.57
# Emissions[oil,net_zero,2030] = 0.36
# Cost[oil,net_zero,2030] = 45.9
# Gen_Emission_Linkage[oil,net_zero,2030] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[oil,net_zero,2030] = 0.35837090000000005
# Negative_Emissions_Deviation[oil,net_zero,2030] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2030] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Generation_Capacity[coal,net_zero,2030] = 2.06
# Generation[coal,net_zero,2030] = 0.0
# Emissions[coal,net_zero,2030] = 0.0
# Cost[coal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[coal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2030] = 8.28
# Positive_Emissions_Deviation[coal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2030] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Generation_Capacity[wind,net_zero,2035] = 50.71
# Generation[wind,net_zero,2035] = 184305.21
# Emissions[wind,net_zero,2035] = 0.0
# Cost[wind,net_zero,2035] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2035] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2035] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Generation_Capacity[solar,net_zero,2035] = 25.05
# Generation[solar,net_zero,2035] = 42161.81
# Emissions[solar,net_zero,2035] = 0.0
# Cost[solar,net_zero,2035] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2035] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2035] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Generation_Capacity[hydro,net_zero,2035] = 92.08
# Generation[hydro,net_zero,2035] = 465887.5
# Emissions[hydro,net_zero,2035] = 0.0
# Cost[hydro,net_zero,2035] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2035] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Generation_Capacity[nuclear,net_zero,2035] = 18.56
# Generation[nuclear,net_zero,2035] = 131692.29
# Emissions[nuclear,net_zero,2035] = 0.0
# Cost[nuclear,net_zero,2035] = 15.75
# Gen_Emission_Linkage[nuclear,net_zero,2035] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2035] = 0.42
# Positive_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Generation_Capacity[natural_gas,net_zero,2035] = 38.39
# Generation[natural_gas,net_zero,2035] = 41866.65
# Emissions[natural_gas,net_zero,2035] = 15.49
# Cost[natural_gas,net_zero,2035] = 15.75
# Gen_Emission_Linkage[natural_gas,net_zero,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[natural_gas,net_zero,2035] = 15.4902905
# Negative_Emissions_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Generation_Capacity[geothermal,net_zero,2035] = 4.03
# Generation[geothermal,net_zero,2035] = 19716.07
# Emissions[geothermal,net_zero,2035] = 0.0
# Cost[geothermal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[geothermal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2035] = 1.35
# Positive_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Generation_Capacity[oil,net_zero,2035] = 2.99
# Generation[oil,net_zero,2035] = 726.09
# Emissions[oil,net_zero,2035] = 0.27
# Cost[oil,net_zero,2035] = 15.75
# Gen_Emission_Linkage[oil,net_zero,2035] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[oil,net_zero,2035] = 0.2682833
# Negative_Emissions_Deviation[oil,net_zero,2035] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2035] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Generation_Capacity[coal,net_zero,2035] = 0.0
# Generation[coal,net_zero,2035] = 0.0
# Emissions[coal,net_zero,2035] = 0.0
# Cost[coal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[coal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2035] = 2.84
# Positive_Emissions_Deviation[coal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2035] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47

# %% [markdown]
# ## Pessimist Model

# %%
import pandas as pd
import gurobipy as gb
from gurobipy import *

# Define the probabilities of scenarios
Ps = {
    "current": 0.8,
    "net_zero": 0.2,
}

# Define Sets
S = ["current", "net_zero"]
T = [2025, 2030, 2035]
G = ["wind", "solar", "hydro", "nuclear", "natural_gas", "geothermal", "oil", "coal"]

# Read each sheet into a DataFrame
df_Dst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Electricity Demand')
df_Lgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Output Targets')
df_Ugst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Generation Capacity Targets')
df_Eg = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Factor')
df_Cgst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Cost')
df_Bst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Emissions Cap')
df_Kst = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Capital Expenditure Budget')

df_dev_e = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_E')
df_dev_g = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_G')
df_dev_q = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_Q')
df_dev_c = pd.read_excel(r"C:\Users\Aasna\Downloads\project data extra model (1).xlsx", sheet_name='Dev_C')

# Convert DataFrames to dictionaries
Dst = df_Dst.set_index(['Scenario', 'Year']).to_dict()['Electricity Demand (GWh)']
Lgst = df_Lgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Output Targets (GWh)']
Ugst = df_Ugst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Generation Capacity Targets (GW)']
Cgst = df_Cgst.set_index(['Technology', 'Scenario', 'Year']).to_dict()['Cost (Millions$/GW)']
Bst = df_Bst.set_index(['Technology','Scenario', 'Year']).to_dict()['Emissions Cap (MtCO2)']
Eg = df_Eg.set_index(['Technology','Scenario','Year']).to_dict()['Emissions Factor (MtCO2/GWh)']
Kst = {scenario: df_Kst[df_Kst['Scenario'] == scenario].set_index('Year')['Value'].to_dict() for scenario in df_Kst['Scenario'].unique()}

dev_e_plus = df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_g_plus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_q_plus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% UB']
dev_c_plus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% UB']

dev_e_minus= df_dev_e.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_g_minus = df_dev_g.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_q_minus = df_dev_q.set_index(['Technology','Scenario', 'Year']).to_dict()['Deviation 5% LB']
dev_c_minus = df_dev_c.set_index(['Technology', 'Scenario','Year']).to_dict()['Deviation 5% LB']

# Create Model
m = Model("CanadaEnergyModel")

# Decision Variables
X = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation_Capacity")
Y = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Generation")
Z = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Emissions")
C = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cost")
W = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Gen_Emission_Linkage")
V = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, lb=0, name="Cap_Cost_Linkage")

# Deviation Variables
et_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Emissions_Deviation")
et_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Emissions_Deviation")
ct_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Cost_Deviation")
ct_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Cost_Deviation")
gt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Deviation")
gt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Deviation")
qt_plus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Positive_Generation_Capacity_Deviation")
qt_minus = m.addVars(G, S, T, vtype=GRB.CONTINUOUS, name="Negative_Generation_Capacity_Deviation")
# Set upper bounds for positive deviation variables based on data from Excel
for g in G:
    for s in S:
        for t in T:
            et_plus[g, s, t].ub = dev_e_plus.get((g, s, t), 0)
            ct_plus[g, s, t].ub = dev_c_plus.get((g, s, t), 0)
            gt_plus[g, s, t].ub = dev_g_plus.get((g, s, t), 0)
            qt_plus[g,s,t].ub = dev_q_plus.get((g,s,t), 0)


#Set upper bounds for negative deviation variables based on data from Excel
for g in G:
   for s in S:
        for t in T:
            et_minus[g,s,t].ub = dev_e_minus.get((g,s,t), 0)
            ct_minus[g,s,t].ub = dev_c_minus.get((g,s,t), 0)
            gt_minus[g,s,t].ub = dev_g_minus.get((g,s,t), 0)
            qt_minus[g,s,t].ub = dev_q_minus.get((g,s,t), 0)
            

# Constraints

# Probability sum constraint
probability_sum_constraint = m.addConstr((sum(Ps[s] for s in S) == 1), name="Probability_Sum")

# Electricity demand constraints
demand_constraints = {}
for s in S:
    for t in T:
        demand_constraints[s, t] = m.addConstr(
            sum(Y[g, s, t] for g in G) <= Dst[(s, t)],
            name=f"Demand_{s}_{t}",
        )

# Generation capacity limit constraints
capacity_limit_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_limit_constraints[g, s, t] = m.addConstr(
                Y[g, s, t] <= X[g, s, t] * 8760 * 1,
                name=f"Capacity_Limit_{g}_{s}_{t}",
            )

# Emission constraints
emission_constraints = {}
for s in S:
    for t in T:
        emission_constraints[s, t] = m.addConstr(
            sum(Z[g, s, t] for g in G) <= (Bst[(g,s, t)] + et_plus.sum('*', s, t) - et_minus.sum('*', s, t)),
            name=f"Emission_{g}_{s}_{t}",
        )

# Capital expenditure constraints
for s in S:
    for t in T:
        m.addConstr(
            sum(C[g, s, t] for g in G) <= Kst[s][t] + ct_plus.sum('*', s, t) - ct_minus.sum('*', s, t),
            name=f"CapEx_{s}_{t}",
        )

# Generation target constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] >= Lgst[(g, s, t)] - gt_plus[g, s, t] + gt_minus[g, s, t],
                name=f"Generation_Target_{g}_{s}_{t}",
            )

# Generation capacity target constraints
capacity_target_constraints = {}
for g in G:
    for s in S:
        for t in T:
            capacity_target_constraints[g, s, t] = m.addConstr(
                X[g, s, t] >= Ugst[(g, s, t)] - qt_plus[g, s, t] + qt_minus[g, s, t],
                name=f"Capacity_Target_{g}_{s}_{t}",
            )


# Define the emissions linking constraints dictionary
emissions_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            emissions_linking_constraints[g, s, t] = m.addConstr(
                Z[g, s, t] == Y[g, s, t] * Eg[g, s, t],
                name=f"Emission_Linking_{g}_{s}_{t}",
            )


# Cost linking constraints
cost_linking_constraints = {}
for g in G:
    for s in S:
        for t in T:
            cost_linking_constraints[g, s, t] = m.addConstr(
                C[g, s, t] == V[g, s, t] * Cgst[(g, s, t)],
                name=f"Cost_Linking_{g}_{s}_{t}",
            )

# Emissions goal achievement constraints
for g in G:
    for s in S:
       for t in T:
            m.addConstr(
                Z[g, s, t] - et_plus[g, s, t] + et_minus[g, s, t]
               == Eg[g, s, t],
               name=f"Emissions_Goal_{g}_{s}_{t}",
            )

# Cost goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                C[g, s, t] - ct_plus[g, s, t] + ct_minus[g, s, t]
                == Bst[g,s, t],
                name=f"Cost_Goal_{g}_{s}_{t}",
            )

# Generation goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                Y[g, s, t] - gt_plus[g, s, t] + gt_minus[g, s, t]
                == Lgst[g, s, t],
                name=f"Generation_Goal_{g}_{s}_{t}",
            )

# Generation capacity goal achievement constraints
for g in G:
    for s in S:
        for t in T:
            m.addConstr(
                X[g, s, t] - qt_plus[g, s, t] + qt_minus[g, s, t]
                == Ugst[g, s, t],
                name=f"Capacity_Goal_{g}_{s}_{t}",
            )

# Define the multiple objectives
objectives = {
    "Emissions_Deviation": {"expr": LinExpr(), "priority": 3},
    "Generation_Deviation": {"expr": LinExpr(), "priority": 2},
    "Capacity_Deviation": {"expr": LinExpr(), "priority": 1},
    "Cost_Deviation": {"expr": LinExpr(), "priority": 0},
}

# Loop through scenarios
for s in S:
  # Loop through time periods
  for t in T:
    # Loop through generation technologies
    for g in G:
      # Objective expressions with g, s, t indexing
      objectives["Emissions_Deviation"]["expr"] += Ps[s] * (et_plus[g,s,t] + et_minus[g,s,t])
      objectives["Generation_Deviation"]["expr"] += Ps[s] * (gt_plus[g,s,t] + gt_minus[g,s,t])
      objectives["Capacity_Deviation"]["expr"] += Ps[s] * (qt_plus[g,s,t] + qt_minus[g,s,t])
      objectives["Cost_Deviation"]["expr"] += Ps[s] * (ct_plus[g,s,t] + ct_minus[g,s,t])

# Set the objectives using setObjectiveN
for i, (obj_name, obj_data) in enumerate(objectives.items()):
  m.setObjectiveN(obj_data["expr"], index=i, priority=obj_data["priority"], name=obj_name)

# Optimize the model
m.optimize()

# Rounding function
def round_to_2(val):
    return round(val, 2)


if m.status == GRB.OPTIMAL:
    print("Optimal Solution Found. Printing Values:")

    for s in S:
        for t in T:
            print(f"\nScenario: {s}, Time Period: {t}")
            for g in G:
                print(f"  Technology: {g}")
                generation = Y[g, s, t].x  # Use actual generation instead of capacity
                cost_per_gw = Cgst[(g, s, t)]
                total_cost = generation * cost_per_gw
                print(f"    Generation: {round_to_2(generation)} GWh")
                print(f"    Generation Capacity: {round_to_2(X[g, s, t].x)} GW")
                print(f"    Emissions: {round_to_2(Z[g, s, t].x)} MtCO2e")
                print(f"    Costs: ${round_to_2(total_cost)}")
                # Adding unrounded positive and negative deviations
                print(f"    Positive Emissions Deviation: {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"    Negative Emissions Deviation: {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")
                print(f"    Positive Cost Deviation: {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")
                print(f"    Negative Cost Deviation: {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Deviation: {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Deviation: {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")
                print(f"    Positive Generation Capacity Deviation: {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")
                print(f"    Negative Generation Capacity Deviation: {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

if m.status == GRB.OPTIMAL:

        # Retrieve and print the values for each objective
    for i, obj_name in enumerate(objectives.keys()):
        m.setParam(GRB.Param.ObjNumber, i)
        obj_value = m.ObjNVal
        print(f"Objective '{obj_name}' Value: {obj_value}")
        
    # Print rounded variable values
    print("Variable Values:")
    for s in S:
        for t in T:
            for g in G:

                # Generation capacity
                rounded_X = round_to_2(X[g, s, t].x) if X[g, s, t] is not None else 0
                print(f"{X[g, s, t].varName} = {rounded_X}")

                # Generation
                rounded_Y = round_to_2(Y[g, s, t].x) if Y[g, s, t] is not None else 0
                print(f"{Y[g, s, t].varName} = {rounded_Y}")

                # Emissions
                rounded_Z = round_to_2(Z[g, s, t].x) if Z[g, s, t] is not None else 0
                print(f"{Z[g, s, t].varName} = {rounded_Z}")

                # Costs
                rounded_C = round_to_2(C[g, s, t].x) if C[g, s, t] is not None else 0
                print(f"{C[g, s, t].varName} = {rounded_C}")

                # Emission linkage
                rounded_W = round_to_2(W[g, s, t].x) if W[g, s, t] is not None else 0
                print(f"{W[g, s, t].varName} = {rounded_W}")

                # Cost linkage
                rounded_V = round_to_2(V[g, s, t].x) if V[g, s, t] is not None else 0
                print(f"{V[g, s, t].varName} = {rounded_V}")

                # Emissions deviation
                print(f"{et_plus[g, s, t].varName} = {et_plus[g, s, t].x if et_plus[g, s, t] is not None else 0}")
                print(f"{et_minus[g, s, t].varName} = {et_minus[g, s, t].x if et_minus[g, s, t] is not None else 0}")

                # Cost deviation
                print(f"{ct_plus[g, s, t].varName} = {ct_plus[g, s, t].x if ct_plus[g, s, t] is not None else 0}")

                print(f"{ct_minus[g, s, t].varName} = {ct_minus[g, s, t].x if ct_minus[g, s, t] is not None else 0}")

                # Generation deviation
                print(f"{gt_plus[g, s, t].varName} = {gt_plus[g, s, t].x if gt_plus[g, s, t] is not None else 0}")

                print(f"{gt_minus[g, s, t].varName} = {gt_minus[g, s, t].x if gt_minus[g, s, t] is not None else 0}")

                # Capacity deviation
                print(f"{qt_plus[g, s, t].varName} = {qt_plus[g, s, t].x if qt_plus[g, s, t] is not None else 0}")

                print(f"{qt_minus[g, s, t].varName} = {qt_minus[g, s, t].x if qt_minus[g, s, t] is not None else 0}")

        # Print totals for each decision variable in each scenario and time period
        for s in S:
            for t in T:
                total_gen_st = sum(Y[g, s, t].x for g in G)
                total_cap_st = sum(X[g, s, t].x for g in G)
                total_emission_st = sum(Z[g, s, t].x for g in G)
                total_cost_st = sum(C[g, s, t].x for g in G)

                print("--------------------------------------------------")
                print(f"Scenario: {s}, Time Period: {t}")
                print(f"Total Generation (GWh): {round_to_2(total_gen_st)}")
                print(f"Total Capacity (GW): {round_to_2(total_cap_st)}")
                print(f"Total Emissions (MtCO2e): {round_to_2(total_emission_st)}")
                print(f"Total Cost (Million CAD): ${round_to_2(total_cost_st)}")
                print("--------------------------------------------------\n")

        # Sum decision variables over G, S, and T dimensions for overall total
        total_gen = sum(Y[g, s, t].x for g in G for s in S for t in T)
        total_cap = sum(X[g, s, t].x for g in G for s in S for t in T)
        total_emission = sum(Z[g, s, t].x for g in G for s in S for t in T)
        total_cost = sum(C[g, s, t].x for g in G for s in S for t in T)

        print("\nOverall Total Across All Scenarios and Time Periods:")
        print(f"Total Generation (GWh): {round_to_2(total_gen)}")
        print(f"Total Capacity (GW): {round_to_2(total_cap)}")
        print(f"Total Emissions (MtCO2e): {round_to_2(total_emission)}")
        print(f"Total Cost (Million CAD): ${round_to_2(total_cost)}")

else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 451 rows, 672 columns and 1458 nonzeros
# Model fingerprint: 0xc6cbe628
# Variable types: 672 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 9e+03]
#   Objective range  [2e-01, 8e-01]
#   Bounds range     [2e+00, 5e+05]
#   RHS range        [4e-04, 9e+05]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 4 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 245 rows and 254 columns
# Presolved: 206 rows and 418 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (Emissions_Deviatio) ...
# ---------------------------------------------------------------------------
#
# Presolve removed 206 rows and 418 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3479922e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.347992215e+02
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Generation_Deviati) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4259350e+04   0.000000e+00   4.880000e+01      0s
#       22    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 (Capacity_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1829592e+02   0.000000e+00   2.437000e+03      0s
#       46    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 46 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 (Cost_Deviation) ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4785939e+02   0.000000e+00   4.200000e+01      0s
#       24    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.09 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.10 seconds (0.00 work units), solution count 4
#
# Optimal Solution Found. Printing Values:
#
# Scenario: current, Time Period: 2025
#   Technology: wind
#     Generation: 57101.82 GWh
#     Generation Capacity: 17.3 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $177035.43
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 12140.31 GWh
#     Generation Capacity: 7.52 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28592.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 403350.8 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4547860.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78631.37 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1466147.94
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 106529.07 GWh
#     Generation Capacity: 30.16 GW
#     Emissions: 39.42 MtCO2e
#     Costs: $230534.5
#     Positive Emissions Deviation: 39.415385900000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7838.55 GWh
#     Generation Capacity: 7.59 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $131786.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1379.91 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.51 MtCO2e
#     Costs: $2986.2
#     Positive Emissions Deviation: 0.5101967000000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8132.43 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.18 MtCO2e
#     Costs: $45104.49
#     Positive Emissions Deviation: 6.179886800000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2030
#   Technology: wind
#     Generation: 80924.64 GWh
#     Generation Capacity: 23.51 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $255911.91
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 13604.24 GWh
#     Generation Capacity: 8.49 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $28836.27
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 437950.3 GWh
#     Generation Capacity: 87.42 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5333015.4
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 82353.64 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2165129.2
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 128115.9 GWh
#     Generation Capacity: 40.33 GW
#     Emissions: 47.4 MtCO2e
#     Costs: $263387.52
#     Positive Emissions Deviation: 47.402513
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 9304.8 GWh
#     Generation Capacity: 8.85 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $137665.08
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 738.59 GWh
#     Generation Capacity: 3.52 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1518.43
#     Positive Emissions Deviation: 0.27290830000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: current, Time Period: 2035
#   Technology: wind
#     Generation: 111348.8 GWh
#     Generation Capacity: 32.47 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $352123.71
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 25234.24 GWh
#     Generation Capacity: 15.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $48138.8
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 438949.6 GWh
#     Generation Capacity: 87.64 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5772801.11
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 90553.33 GWh
#     Generation Capacity: 11.9 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $3356793.92
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 130754.2 GWh
#     Generation Capacity: 44.8 GW
#     Emissions: 48.38 MtCO2e
#     Costs: $255371.19
#     Positive Emissions Deviation: 48.378684
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 17493.74 GWh
#     Generation Capacity: 11.48 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $204468.62
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 498.39 GWh
#     Generation Capacity: 3.02 GW
#     Emissions: 0.18 MtCO2e
#     Costs: $973.39
#     Positive Emissions Deviation: 0.18403429999999998
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2025
#   Technology: wind
#     Generation: 60429.05 GWh
#     Generation Capacity: 18.24 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $187350.99
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 11707.13 GWh
#     Generation Capacity: 7.31 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $27572.19
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 401733.6 GWh
#     Generation Capacity: 84.91 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4529626.69
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 78278.04 GWh
#     Generation Capacity: 12.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $1459559.81
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 98076.85 GWh
#     Generation Capacity: 31.54 GW
#     Emissions: 36.29 MtCO2e
#     Costs: $212243.45
#     Positive Emissions Deviation: 36.288064500000004
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 8281.2 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $139228.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 1355.5 GWh
#     Generation Capacity: 3.67 GW
#     Emissions: 0.5 MtCO2e
#     Costs: $2933.37
#     Positive Emissions Deviation: 0.501165
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 8184.54 GWh
#     Generation Capacity: 2.93 GW
#     Emissions: 6.22 MtCO2e
#     Costs: $45393.5
#     Positive Emissions Deviation: 6.219490400000001
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2030
#   Technology: wind
#     Generation: 92547.75 GWh
#     Generation Capacity: 25.21 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $292668.24
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 15214.42 GWh
#     Generation Capacity: 9.5 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $32249.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 443103.1 GWh
#     Generation Capacity: 88.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $5395762.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 87724.81 GWh
#     Generation Capacity: 11.11 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $2306340.65
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 122942.64 GWh
#     Generation Capacity: 39.71 GW
#     Emissions: 45.49 MtCO2e
#     Costs: $252752.06
#     Positive Emissions Deviation: 45.4884068
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 7526.04 GWh
#     Generation Capacity: 2.58 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $111348.22
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 969.57 GWh
#     Generation Capacity: 3.49 GW
#     Emissions: 0.36 MtCO2e
#     Costs: $1993.29
#     Positive Emissions Deviation: 0.35837090000000005
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 2.06 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#
# Scenario: net_zero, Time Period: 2035
#   Technology: wind
#     Generation: 184305.21 GWh
#     Generation Capacity: 50.71 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $582837.3
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: solar
#     Generation: 42161.81 GWh
#     Generation Capacity: 25.05 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $80431.16
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: hydro
#     Generation: 465887.5 GWh
#     Generation Capacity: 92.08 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $6127072.17
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: nuclear
#     Generation: 131692.29 GWh
#     Generation Capacity: 18.56 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $4881806.98
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: natural_gas
#     Generation: 41866.65 GWh
#     Generation Capacity: 38.39 GW
#     Emissions: 15.49 MtCO2e
#     Costs: $81768.21
#     Positive Emissions Deviation: 15.4902905
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: geothermal
#     Generation: 19716.07 GWh
#     Generation Capacity: 4.03 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $230443.44
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: oil
#     Generation: 726.09 GWh
#     Generation Capacity: 2.99 GW
#     Emissions: 0.27 MtCO2e
#     Costs: $1418.1
#     Positive Emissions Deviation: 0.2682833
#     Negative Emissions Deviation: 0.0
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
#   Technology: coal
#     Generation: 0.0 GWh
#     Generation Capacity: 0.0 GW
#     Emissions: 0.0 MtCO2e
#     Costs: $0.0
#     Positive Emissions Deviation: 0.0
#     Negative Emissions Deviation: 0.00076
#     Positive Cost Deviation: 0.0
#     Negative Cost Deviation: 0.0
#     Positive Generation Deviation: 0.0
#     Negative Generation Deviation: 0.0
#     Positive Generation Capacity Deviation: 0.0
#     Negative Generation Capacity Deviation: 0.0
# Objective 'Emissions_Deviation' Value: 134.79922148
# Objective 'Generation_Deviation' Value: 0.0
# Objective 'Capacity_Deviation' Value: 0.0
# Objective 'Cost_Deviation' Value: 0.0
# Variable Values:
# Generation_Capacity[wind,current,2025] = 17.3
# Generation[wind,current,2025] = 57101.82
# Emissions[wind,current,2025] = 0.0
# Cost[wind,current,2025] = 0.0
# Gen_Emission_Linkage[wind,current,2025] = 0.0
# Cap_Cost_Linkage[wind,current,2025] = 0.0
# Positive_Emissions_Deviation[wind,current,2025] = 0.0
# Negative_Emissions_Deviation[wind,current,2025] = 0.0
# Positive_Cost_Deviation[wind,current,2025] = 0.0
# Negative_Cost_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Deviation[wind,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2025] = 0.0
# Generation_Capacity[solar,current,2025] = 7.52
# Generation[solar,current,2025] = 12140.31
# Emissions[solar,current,2025] = 0.0
# Cost[solar,current,2025] = 0.0
# Gen_Emission_Linkage[solar,current,2025] = 0.0
# Cap_Cost_Linkage[solar,current,2025] = 0.0
# Positive_Emissions_Deviation[solar,current,2025] = 0.0
# Negative_Emissions_Deviation[solar,current,2025] = 0.0
# Positive_Cost_Deviation[solar,current,2025] = 0.0
# Negative_Cost_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Deviation[solar,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2025] = 0.0
# Generation_Capacity[hydro,current,2025] = 84.91
# Generation[hydro,current,2025] = 403350.8
# Emissions[hydro,current,2025] = 0.0
# Cost[hydro,current,2025] = 0.0
# Gen_Emission_Linkage[hydro,current,2025] = 0.0
# Cap_Cost_Linkage[hydro,current,2025] = 0.0
# Positive_Emissions_Deviation[hydro,current,2025] = 0.0
# Negative_Emissions_Deviation[hydro,current,2025] = 0.0
# Positive_Cost_Deviation[hydro,current,2025] = 0.0
# Negative_Cost_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Deviation[hydro,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2025] = 0.0
# Generation_Capacity[nuclear,current,2025] = 12.11
# Generation[nuclear,current,2025] = 78631.37
# Emissions[nuclear,current,2025] = 0.0
# Cost[nuclear,current,2025] = 0.0
# Gen_Emission_Linkage[nuclear,current,2025] = 0.0
# Cap_Cost_Linkage[nuclear,current,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2025] = 0.0
# Positive_Cost_Deviation[nuclear,current,2025] = 0.0
# Negative_Cost_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Deviation[nuclear,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2025] = 0.0
# Generation_Capacity[natural_gas,current,2025] = 30.16
# Generation[natural_gas,current,2025] = 106529.07
# Emissions[natural_gas,current,2025] = 39.42
# Cost[natural_gas,current,2025] = 46.1
# Gen_Emission_Linkage[natural_gas,current,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2025] = 21.3
# Positive_Emissions_Deviation[natural_gas,current,2025] = 39.415385900000004
# Negative_Emissions_Deviation[natural_gas,current,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2025] = 0.0
# Generation_Capacity[geothermal,current,2025] = 7.59
# Generation[geothermal,current,2025] = 7838.55
# Emissions[geothermal,current,2025] = 0.0
# Cost[geothermal,current,2025] = 46.1
# Gen_Emission_Linkage[geothermal,current,2025] = 0.0
# Cap_Cost_Linkage[geothermal,current,2025] = 2.74
# Positive_Emissions_Deviation[geothermal,current,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2025] = 0.0
# Positive_Cost_Deviation[geothermal,current,2025] = 0.0
# Negative_Cost_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Deviation[geothermal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2025] = 0.0
# Generation_Capacity[oil,current,2025] = 3.67
# Generation[oil,current,2025] = 1379.91
# Emissions[oil,current,2025] = 0.51
# Cost[oil,current,2025] = 46.1
# Gen_Emission_Linkage[oil,current,2025] = 0.0
# Cap_Cost_Linkage[oil,current,2025] = 21.3
# Positive_Emissions_Deviation[oil,current,2025] = 0.5101967000000001
# Negative_Emissions_Deviation[oil,current,2025] = 0.0
# Positive_Cost_Deviation[oil,current,2025] = 0.0
# Negative_Cost_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Deviation[oil,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2025] = 0.0
# Generation_Capacity[coal,current,2025] = 2.93
# Generation[coal,current,2025] = 8132.43
# Emissions[coal,current,2025] = 6.18
# Cost[coal,current,2025] = 46.1
# Gen_Emission_Linkage[coal,current,2025] = 0.0
# Cap_Cost_Linkage[coal,current,2025] = 8.31
# Positive_Emissions_Deviation[coal,current,2025] = 6.179886800000001
# Negative_Emissions_Deviation[coal,current,2025] = 0.0
# Positive_Cost_Deviation[coal,current,2025] = 0.0
# Negative_Cost_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Deviation[coal,current,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2025] = 0.0
# Generation_Capacity[wind,current,2030] = 23.51
# Generation[wind,current,2030] = 80924.64
# Emissions[wind,current,2030] = 0.0
# Cost[wind,current,2030] = 0.0
# Gen_Emission_Linkage[wind,current,2030] = 0.0
# Cap_Cost_Linkage[wind,current,2030] = 0.0
# Positive_Emissions_Deviation[wind,current,2030] = 0.0
# Negative_Emissions_Deviation[wind,current,2030] = 0.0
# Positive_Cost_Deviation[wind,current,2030] = 0.0
# Negative_Cost_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Deviation[wind,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2030] = 0.0
# Generation_Capacity[solar,current,2030] = 8.49
# Generation[solar,current,2030] = 13604.24
# Emissions[solar,current,2030] = 0.0
# Cost[solar,current,2030] = 0.0
# Gen_Emission_Linkage[solar,current,2030] = 0.0
# Cap_Cost_Linkage[solar,current,2030] = 0.0
# Positive_Emissions_Deviation[solar,current,2030] = 0.0
# Negative_Emissions_Deviation[solar,current,2030] = 0.0
# Positive_Cost_Deviation[solar,current,2030] = 0.0
# Negative_Cost_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Deviation[solar,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2030] = 0.0
# Generation_Capacity[hydro,current,2030] = 87.42
# Generation[hydro,current,2030] = 437950.3
# Emissions[hydro,current,2030] = 0.0
# Cost[hydro,current,2030] = 0.0
# Gen_Emission_Linkage[hydro,current,2030] = 0.0
# Cap_Cost_Linkage[hydro,current,2030] = 0.0
# Positive_Emissions_Deviation[hydro,current,2030] = 0.0
# Negative_Emissions_Deviation[hydro,current,2030] = 0.0
# Positive_Cost_Deviation[hydro,current,2030] = 0.0
# Negative_Cost_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Deviation[hydro,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2030] = 0.0
# Generation_Capacity[nuclear,current,2030] = 11.11
# Generation[nuclear,current,2030] = 82353.64
# Emissions[nuclear,current,2030] = 0.0
# Cost[nuclear,current,2030] = 0.0
# Gen_Emission_Linkage[nuclear,current,2030] = 0.0
# Cap_Cost_Linkage[nuclear,current,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2030] = 0.0
# Positive_Cost_Deviation[nuclear,current,2030] = 0.0
# Negative_Cost_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Deviation[nuclear,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2030] = 0.0
# Generation_Capacity[natural_gas,current,2030] = 40.33
# Generation[natural_gas,current,2030] = 128115.9
# Emissions[natural_gas,current,2030] = 47.4
# Cost[natural_gas,current,2030] = 47.67
# Gen_Emission_Linkage[natural_gas,current,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2030] = 23.19
# Positive_Emissions_Deviation[natural_gas,current,2030] = 47.402513
# Negative_Emissions_Deviation[natural_gas,current,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2030] = 0.0
# Generation_Capacity[geothermal,current,2030] = 8.85
# Generation[geothermal,current,2030] = 9304.8
# Emissions[geothermal,current,2030] = 0.0
# Cost[geothermal,current,2030] = 47.67
# Gen_Emission_Linkage[geothermal,current,2030] = 0.0
# Cap_Cost_Linkage[geothermal,current,2030] = 3.22
# Positive_Emissions_Deviation[geothermal,current,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2030] = 0.0
# Positive_Cost_Deviation[geothermal,current,2030] = 0.0
# Negative_Cost_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Deviation[geothermal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2030] = 0.0
# Generation_Capacity[oil,current,2030] = 3.52
# Generation[oil,current,2030] = 738.59
# Emissions[oil,current,2030] = 0.27
# Cost[oil,current,2030] = 47.67
# Gen_Emission_Linkage[oil,current,2030] = 0.0
# Cap_Cost_Linkage[oil,current,2030] = 23.19
# Positive_Emissions_Deviation[oil,current,2030] = 0.27290830000000005
# Negative_Emissions_Deviation[oil,current,2030] = 0.0
# Positive_Cost_Deviation[oil,current,2030] = 0.0
# Negative_Cost_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Deviation[oil,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2030] = 0.0
# Generation_Capacity[coal,current,2030] = 2.06
# Generation[coal,current,2030] = 0.0
# Emissions[coal,current,2030] = 0.0
# Cost[coal,current,2030] = 47.67
# Gen_Emission_Linkage[coal,current,2030] = 0.0
# Cap_Cost_Linkage[coal,current,2030] = 8.59
# Positive_Emissions_Deviation[coal,current,2030] = 0.0
# Negative_Emissions_Deviation[coal,current,2030] = 0.00076
# Positive_Cost_Deviation[coal,current,2030] = 0.0
# Negative_Cost_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Deviation[coal,current,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2030] = 0.0
# Generation_Capacity[wind,current,2035] = 32.47
# Generation[wind,current,2035] = 111348.8
# Emissions[wind,current,2035] = 0.0
# Cost[wind,current,2035] = 0.0
# Gen_Emission_Linkage[wind,current,2035] = 0.0
# Cap_Cost_Linkage[wind,current,2035] = 0.0
# Positive_Emissions_Deviation[wind,current,2035] = 0.0
# Negative_Emissions_Deviation[wind,current,2035] = 0.0
# Positive_Cost_Deviation[wind,current,2035] = 0.0
# Negative_Cost_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Deviation[wind,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,current,2035] = 0.0
# Generation_Capacity[solar,current,2035] = 15.58
# Generation[solar,current,2035] = 25234.24
# Emissions[solar,current,2035] = 0.0
# Cost[solar,current,2035] = 0.0
# Gen_Emission_Linkage[solar,current,2035] = 0.0
# Cap_Cost_Linkage[solar,current,2035] = 0.0
# Positive_Emissions_Deviation[solar,current,2035] = 0.0
# Negative_Emissions_Deviation[solar,current,2035] = 0.0
# Positive_Cost_Deviation[solar,current,2035] = 0.0
# Negative_Cost_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Deviation[solar,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,current,2035] = 0.0
# Generation_Capacity[hydro,current,2035] = 87.64
# Generation[hydro,current,2035] = 438949.6
# Emissions[hydro,current,2035] = 0.0
# Cost[hydro,current,2035] = 0.0
# Gen_Emission_Linkage[hydro,current,2035] = 0.0
# Cap_Cost_Linkage[hydro,current,2035] = 0.0
# Positive_Emissions_Deviation[hydro,current,2035] = 0.0
# Negative_Emissions_Deviation[hydro,current,2035] = 0.0
# Positive_Cost_Deviation[hydro,current,2035] = 0.0
# Negative_Cost_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Deviation[hydro,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,current,2035] = 0.0
# Generation_Capacity[nuclear,current,2035] = 11.9
# Generation[nuclear,current,2035] = 90553.33
# Emissions[nuclear,current,2035] = 0.0
# Cost[nuclear,current,2035] = 0.0
# Gen_Emission_Linkage[nuclear,current,2035] = 0.0
# Cap_Cost_Linkage[nuclear,current,2035] = 0.0
# Positive_Emissions_Deviation[nuclear,current,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,current,2035] = 0.0
# Positive_Cost_Deviation[nuclear,current,2035] = 0.0
# Negative_Cost_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Deviation[nuclear,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,current,2035] = 0.0
# Generation_Capacity[natural_gas,current,2035] = 44.8
# Generation[natural_gas,current,2035] = 130754.2
# Emissions[natural_gas,current,2035] = 48.38
# Cost[natural_gas,current,2035] = 48.56
# Gen_Emission_Linkage[natural_gas,current,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,current,2035] = 24.86
# Positive_Emissions_Deviation[natural_gas,current,2035] = 48.378684
# Negative_Emissions_Deviation[natural_gas,current,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,current,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,current,2035] = 0.0
# Generation_Capacity[geothermal,current,2035] = 11.48
# Generation[geothermal,current,2035] = 17493.74
# Emissions[geothermal,current,2035] = 0.0
# Cost[geothermal,current,2035] = 48.56
# Gen_Emission_Linkage[geothermal,current,2035] = 0.0
# Cap_Cost_Linkage[geothermal,current,2035] = 4.15
# Positive_Emissions_Deviation[geothermal,current,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,current,2035] = 0.0
# Positive_Cost_Deviation[geothermal,current,2035] = 0.0
# Negative_Cost_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Deviation[geothermal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,current,2035] = 0.0
# Generation_Capacity[oil,current,2035] = 3.02
# Generation[oil,current,2035] = 498.39
# Emissions[oil,current,2035] = 0.18
# Cost[oil,current,2035] = 48.56
# Gen_Emission_Linkage[oil,current,2035] = 0.0
# Cap_Cost_Linkage[oil,current,2035] = 24.86
# Positive_Emissions_Deviation[oil,current,2035] = 0.18403429999999998
# Negative_Emissions_Deviation[oil,current,2035] = 0.0
# Positive_Cost_Deviation[oil,current,2035] = 0.0
# Negative_Cost_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Deviation[oil,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,current,2035] = 0.0
# Generation_Capacity[coal,current,2035] = 0.0
# Generation[coal,current,2035] = 0.0
# Emissions[coal,current,2035] = 0.0
# Cost[coal,current,2035] = 48.56
# Gen_Emission_Linkage[coal,current,2035] = 0.0
# Cap_Cost_Linkage[coal,current,2035] = 8.76
# Positive_Emissions_Deviation[coal,current,2035] = 0.0
# Negative_Emissions_Deviation[coal,current,2035] = 0.00076
# Positive_Cost_Deviation[coal,current,2035] = 0.0
# Negative_Cost_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Deviation[coal,current,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,current,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47
# Generation_Capacity[wind,net_zero,2025] = 18.24
# Generation[wind,net_zero,2025] = 60429.05
# Emissions[wind,net_zero,2025] = 0.0
# Cost[wind,net_zero,2025] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2025] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2025] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2025] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2025] = 0.0
# Generation_Capacity[solar,net_zero,2025] = 7.31
# Generation[solar,net_zero,2025] = 11707.13
# Emissions[solar,net_zero,2025] = 0.0
# Cost[solar,net_zero,2025] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2025] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2025] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2025] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2025] = 0.0
# Generation_Capacity[hydro,net_zero,2025] = 84.91
# Generation[hydro,net_zero,2025] = 401733.6
# Emissions[hydro,net_zero,2025] = 0.0
# Cost[hydro,net_zero,2025] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2025] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2025] = 0.0
# Generation_Capacity[nuclear,net_zero,2025] = 12.11
# Generation[nuclear,net_zero,2025] = 78278.04
# Emissions[nuclear,net_zero,2025] = 0.0
# Cost[nuclear,net_zero,2025] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2025] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2025] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2025] = 0.0
# Generation_Capacity[natural_gas,net_zero,2025] = 31.54
# Generation[natural_gas,net_zero,2025] = 98076.85
# Emissions[natural_gas,net_zero,2025] = 36.29
# Cost[natural_gas,net_zero,2025] = 43.2
# Gen_Emission_Linkage[natural_gas,net_zero,2025] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[natural_gas,net_zero,2025] = 36.288064500000004
# Negative_Emissions_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2025] = 0.0
# Generation_Capacity[geothermal,net_zero,2025] = 2.58
# Generation[geothermal,net_zero,2025] = 8281.2
# Emissions[geothermal,net_zero,2025] = 0.0
# Cost[geothermal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[geothermal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2025] = 2.57
# Positive_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2025] = 0.0
# Generation_Capacity[oil,net_zero,2025] = 3.67
# Generation[oil,net_zero,2025] = 1355.5
# Emissions[oil,net_zero,2025] = 0.5
# Cost[oil,net_zero,2025] = 43.2
# Gen_Emission_Linkage[oil,net_zero,2025] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2025] = 19.96
# Positive_Emissions_Deviation[oil,net_zero,2025] = 0.501165
# Negative_Emissions_Deviation[oil,net_zero,2025] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2025] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2025] = 0.0
# Generation_Capacity[coal,net_zero,2025] = 2.93
# Generation[coal,net_zero,2025] = 8184.54
# Emissions[coal,net_zero,2025] = 6.22
# Cost[coal,net_zero,2025] = 43.2
# Gen_Emission_Linkage[coal,net_zero,2025] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2025] = 7.79
# Positive_Emissions_Deviation[coal,net_zero,2025] = 6.219490400000001
# Negative_Emissions_Deviation[coal,net_zero,2025] = 0.0
# Positive_Cost_Deviation[coal,net_zero,2025] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2025] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2025] = 0.0
# Generation_Capacity[wind,net_zero,2030] = 25.21
# Generation[wind,net_zero,2030] = 92547.75
# Emissions[wind,net_zero,2030] = 0.0
# Cost[wind,net_zero,2030] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2030] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2030] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2030] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2030] = 0.0
# Generation_Capacity[solar,net_zero,2030] = 9.5
# Generation[solar,net_zero,2030] = 15214.42
# Emissions[solar,net_zero,2030] = 0.0
# Cost[solar,net_zero,2030] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2030] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2030] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2030] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2030] = 0.0
# Generation_Capacity[hydro,net_zero,2030] = 88.08
# Generation[hydro,net_zero,2030] = 443103.1
# Emissions[hydro,net_zero,2030] = 0.0
# Cost[hydro,net_zero,2030] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2030] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2030] = 0.0
# Generation_Capacity[nuclear,net_zero,2030] = 11.11
# Generation[nuclear,net_zero,2030] = 87724.81
# Emissions[nuclear,net_zero,2030] = 0.0
# Cost[nuclear,net_zero,2030] = 0.0
# Gen_Emission_Linkage[nuclear,net_zero,2030] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2030] = 0.0
# Positive_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2030] = 0.0
# Generation_Capacity[natural_gas,net_zero,2030] = 39.71
# Generation[natural_gas,net_zero,2030] = 122942.64
# Emissions[natural_gas,net_zero,2030] = 45.49
# Cost[natural_gas,net_zero,2030] = 45.9
# Gen_Emission_Linkage[natural_gas,net_zero,2030] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[natural_gas,net_zero,2030] = 45.4884068
# Negative_Emissions_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2030] = 0.0
# Generation_Capacity[geothermal,net_zero,2030] = 2.58
# Generation[geothermal,net_zero,2030] = 7526.04
# Emissions[geothermal,net_zero,2030] = 0.0
# Cost[geothermal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[geothermal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2030] = 3.1
# Positive_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2030] = 0.0
# Generation_Capacity[oil,net_zero,2030] = 3.49
# Generation[oil,net_zero,2030] = 969.57
# Emissions[oil,net_zero,2030] = 0.36
# Cost[oil,net_zero,2030] = 45.9
# Gen_Emission_Linkage[oil,net_zero,2030] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2030] = 22.33
# Positive_Emissions_Deviation[oil,net_zero,2030] = 0.35837090000000005
# Negative_Emissions_Deviation[oil,net_zero,2030] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2030] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2030] = 0.0
# Generation_Capacity[coal,net_zero,2030] = 2.06
# Generation[coal,net_zero,2030] = 0.0
# Emissions[coal,net_zero,2030] = 0.0
# Cost[coal,net_zero,2030] = 45.9
# Gen_Emission_Linkage[coal,net_zero,2030] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2030] = 8.28
# Positive_Emissions_Deviation[coal,net_zero,2030] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2030] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2030] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2030] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2030] = 0.0
# Generation_Capacity[wind,net_zero,2035] = 50.71
# Generation[wind,net_zero,2035] = 184305.21
# Emissions[wind,net_zero,2035] = 0.0
# Cost[wind,net_zero,2035] = 0.0
# Gen_Emission_Linkage[wind,net_zero,2035] = 0.0
# Cap_Cost_Linkage[wind,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[wind,net_zero,2035] = 0.0
# Positive_Cost_Deviation[wind,net_zero,2035] = 0.0
# Negative_Cost_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Deviation[wind,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[wind,net_zero,2035] = 0.0
# Generation_Capacity[solar,net_zero,2035] = 25.05
# Generation[solar,net_zero,2035] = 42161.81
# Emissions[solar,net_zero,2035] = 0.0
# Cost[solar,net_zero,2035] = 0.0
# Gen_Emission_Linkage[solar,net_zero,2035] = 0.0
# Cap_Cost_Linkage[solar,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[solar,net_zero,2035] = 0.0
# Positive_Cost_Deviation[solar,net_zero,2035] = 0.0
# Negative_Cost_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Deviation[solar,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[solar,net_zero,2035] = 0.0
# Generation_Capacity[hydro,net_zero,2035] = 92.08
# Generation[hydro,net_zero,2035] = 465887.5
# Emissions[hydro,net_zero,2035] = 0.0
# Cost[hydro,net_zero,2035] = 0.0
# Gen_Emission_Linkage[hydro,net_zero,2035] = 0.0
# Cap_Cost_Linkage[hydro,net_zero,2035] = 0.0
# Positive_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Cost_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Deviation[hydro,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[hydro,net_zero,2035] = 0.0
# Generation_Capacity[nuclear,net_zero,2035] = 18.56
# Generation[nuclear,net_zero,2035] = 131692.29
# Emissions[nuclear,net_zero,2035] = 0.0
# Cost[nuclear,net_zero,2035] = 15.75
# Gen_Emission_Linkage[nuclear,net_zero,2035] = 0.0
# Cap_Cost_Linkage[nuclear,net_zero,2035] = 0.42
# Positive_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Cost_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Deviation[nuclear,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[nuclear,net_zero,2035] = 0.0
# Generation_Capacity[natural_gas,net_zero,2035] = 38.39
# Generation[natural_gas,net_zero,2035] = 41866.65
# Emissions[natural_gas,net_zero,2035] = 15.49
# Cost[natural_gas,net_zero,2035] = 15.75
# Gen_Emission_Linkage[natural_gas,net_zero,2035] = 0.0
# Cap_Cost_Linkage[natural_gas,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[natural_gas,net_zero,2035] = 15.4902905
# Negative_Emissions_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Cost_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Deviation[natural_gas,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[natural_gas,net_zero,2035] = 0.0
# Generation_Capacity[geothermal,net_zero,2035] = 4.03
# Generation[geothermal,net_zero,2035] = 19716.07
# Emissions[geothermal,net_zero,2035] = 0.0
# Cost[geothermal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[geothermal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[geothermal,net_zero,2035] = 1.35
# Positive_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[geothermal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[geothermal,net_zero,2035] = 0.0
# Generation_Capacity[oil,net_zero,2035] = 2.99
# Generation[oil,net_zero,2035] = 726.09
# Emissions[oil,net_zero,2035] = 0.27
# Cost[oil,net_zero,2035] = 15.75
# Gen_Emission_Linkage[oil,net_zero,2035] = 0.0
# Cap_Cost_Linkage[oil,net_zero,2035] = 8.06
# Positive_Emissions_Deviation[oil,net_zero,2035] = 0.2682833
# Negative_Emissions_Deviation[oil,net_zero,2035] = 0.0
# Positive_Cost_Deviation[oil,net_zero,2035] = 0.0
# Negative_Cost_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Deviation[oil,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[oil,net_zero,2035] = 0.0
# Generation_Capacity[coal,net_zero,2035] = 0.0
# Generation[coal,net_zero,2035] = 0.0
# Emissions[coal,net_zero,2035] = 0.0
# Cost[coal,net_zero,2035] = 15.75
# Gen_Emission_Linkage[coal,net_zero,2035] = 0.0
# Cap_Cost_Linkage[coal,net_zero,2035] = 2.84
# Positive_Emissions_Deviation[coal,net_zero,2035] = 0.0
# Negative_Emissions_Deviation[coal,net_zero,2035] = 0.00076
# Positive_Cost_Deviation[coal,net_zero,2035] = 0.0
# Negative_Cost_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Deviation[coal,net_zero,2035] = 0.0
# Positive_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# Negative_Generation_Capacity_Deviation[coal,net_zero,2035] = 0.0
# --------------------------------------------------
# Scenario: current, Time Period: 2025
# Total Generation (GWh): 675104.26
# Total Capacity (GW): 166.2
# Total Emissions (MtCO2e): 46.11
# Total Cost (Million CAD): $184.4
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2030
# Total Generation (GWh): 752992.11
# Total Capacity (GW): 185.29
# Total Emissions (MtCO2e): 47.68
# Total Cost (Million CAD): $190.68
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: current, Time Period: 2035
# Total Generation (GWh): 814832.3
# Total Capacity (GW): 206.91
# Total Emissions (MtCO2e): 48.56
# Total Cost (Million CAD): $194.24
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2025
# Total Generation (GWh): 668045.91
# Total Capacity (GW): 163.29
# Total Emissions (MtCO2e): 43.01
# Total Cost (Million CAD): $172.8
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2030
# Total Generation (GWh): 770028.33
# Total Capacity (GW): 181.74
# Total Emissions (MtCO2e): 45.85
# Total Cost (Million CAD): $183.6
# --------------------------------------------------
#
# --------------------------------------------------
# Scenario: net_zero, Time Period: 2035
# Total Generation (GWh): 886355.62
# Total Capacity (GW): 231.81
# Total Emissions (MtCO2e): 15.76
# Total Cost (Million CAD): $78.75
# --------------------------------------------------
#
#
# Overall Total Across All Scenarios and Time Periods:
# Total Generation (GWh): 4567358.53
# Total Capacity (GW): 1135.24
# Total Emissions (MtCO2e): 246.96
# Total Cost (Million CAD): $1004.47
